# %%
####################################################################################################
# Author: Alexander O. Smith
# Created: Oct 25, 2021
# Updated: Nov 8, 2021
####################################################################################################

# %%
####################################################################################################
# IMPORTS ##########################################################################################
from bs4 import BeautifulSoup as bs  #To Output Clean HTML files (and general scraping)
from lxml import html, etree         #For XPath
from io import StringIO, BytesIO
from urllib.request import Request, urlopen
import urllib.request
import pandas as pd
from datetime import date
from random import randint
from time import sleep
import os, re, random
####################################################################################################

# %%
####################################################################################################
# Version 1 ########################################################################################
def kym_gallery_pull(name='rickroll'):

    # Setup an output file...
    out = open(f'{name}_collection_output.txt',"a+")
    today = date.today()
    dateMDY = today.strftime("%m-%d-%y")
    date_time = today.strftime("%m/%d/%Y, %H:%M:%S")
    out.write(f'KYM_GALLERY_PULL Function Initiated: {date_time}...')
    print(f'KYM_GALLERY_PULL Function Initiated: {date_time}...')

    # Try/Except captures errors in the outfile: 'out'
    try:
        # Set up url connection with BeautifulSoup
        name = re.sub('\s', '-', str(name))
        out.write(f'Collecting image gallery "{name}" from KnowYourMeme.\n')
        #print(f'Collecting image gallery "{name}" from KnowYourMeme.')
        url = f'https://knowyourmeme.com/memes/{name}'
        memeURL = f'{url}/photos/page/1'
        req = Request(str(memeURL), headers={'User-Agent': 'Mozilla/5.0'})
        webpage = urlopen(req).read()
        soup = bs(webpage, 'html.parser', from_encoding="iso-8859-1")

        # Load webpage into ELement Tree format for XPath search for first page image count:
        root = etree.HTML(webpage)
        result = etree.tostring(root, pretty_print=True, method="html")

        n = 1 #begin iterable for each KYM Gallery Page URL
        url_suffixes = [] #being the list of url directorys after the url prefix for each image

        # While loop runs so long as the photo_gallery is not empty
        while len(root.xpath("//a[@rel='photo_gallery']")) != 0:

            # Set up iterable url connection
            out.write(f'Retrieving image hrefs from page {n} of {name} gallery...\n')
            #print(f'Retrieving image hrefs from page {n} of {name} gallery...')
            memeURL = f'{url}/photos/page/{n}'
            req = Request(memeURL, headers={'User-Agent': 'Mozilla/5.0'})
            webpage = urlopen(req).read()
            root = etree.HTML(webpage)
            result = etree.tostring(root, pretty_print=True, method="html")

            url_suffixes = url_suffixes + root.xpath(f'//div/div[@id="photo_gallery"]/div[@class="item"]/a/@href')

            # Iterate to the next n to get the next KYM Gallery Page in 'memeURL' above
            n+=1

        out.write(f'Completed gallery href collection for {name} gallery.\n')
        #print(f'Completed gallery href collection for {name} gallery.')

        # Debugging to check to make sure we got all the images in the gallery
        total_url = len(url_suffixes)
        unique_url = len(pd.unique(url_suffixes))
        if total_url != unique_url:
            out.write(f'''COLLECTION WARNING: Difference between the total URLs - unique URLs is non-zero.\n
                This indicates a loss of {total_url - unique_url} gallery images from KYM.\n
                The total number of unique URLs is {unique_url}.\n''')
            #print(f'''COLLECTION WARNING: Difference between the total URLs - unique URLs is non-zero.\n
            #      This indicates a loss of {total_url - unique_url} gallery images from KYM.\n
            #      The total number of unique URLs is {unique_url}.''')
        else:
            out.write(f'The total number of URLs is {unique_url}.\n')
            #print(f'The total number of URLs is {unique_url}.')

        # Building lists for a metadata dataframe
        lrg_img = []          # large img URLs
        img_IDs = []          # img_IDs
        img_locs = []         # locations of image
        alt_txt = []          # image alt text
        date_upload = []      # image upload date
        views = []            # number of views of each image
        views_today = []      # number of views today for each image
        img_source = []       # given source of image
        pos_votes = []        # positive votes on an image
        neg_votes = []        # negative votes on an image
        kym_tags = []         # tags offered by KYM
        img_edits_url = []    # url extension to image metadata edits
        author = []           # author handle assigned to image

        # Loop saves images and metadata for each image.
        for u in url_suffixes:
            out.write(f'Retrieving img at href {u}\n')
            print(f'Retrieving img at href {u}')
            imgURL = f'{url}{u}'
            out.write(imgURL+'\n')
            print(imgURL)
            reqIMG = Request(str(imgURL), headers={'User-Agent': 'Mozilla/5.0'})
            imgpage = urlopen(reqIMG).read()
            soup = bs(imgpage, 'html.parser') #, from_encoding="iso-8859-1"
            # Load webpage into ELement Tree format for XPath search for first page image count:
            imgRoot = etree.HTML(imgpage)
            # Putting all final image URL locations into 'lrg_img' list.
            img = imgRoot.xpath("*//div[@class='thumbable']//img[contains(@data-src, 'newsfeed')]//@data-src")[0]
            lrg_img.append(img)

            # Using 'img' urls to create a unique ID
            i = img.partition("newsfeed/")[2]
            img_file = re.sub('/', '_',i)
            out.write(f'Retrieving Image {img_file}\n')
            print(f'Retrieving Image {img_file}')
            img_ID = img_file.partition('.')[0]
            # Should be a unique image ID
            img_ID = f'IMG_{img_ID}'
            img_IDs.append(img_ID)

            # Creating an image location name, and making a metadata variable for it
            img_loc = f'{str(name)}-meme'
            img_locs.append(img_loc)

            # KYM image metadata imgRoot location, under "Image Details"
            # For explanation of meanings of the appended metadata, see empty lists defined before loop.
            view = imgRoot.xpath(
              "//aside[@id='sidebar']//span[@class='view_count']/text()")[0]
            views.append(view)
            view_today = imgRoot.xpath(
              "//aside[@id='sidebar']//span[@class='today_view_count']/text()")[0][1:-1] 
            view_today = re.sub('\sfrom\stoday', '', view_today)
            views_today.append(view_today)
            upload = imgRoot.xpath(
              "//aside[@id='sidebar']//abbr[@class='timeago']/@title")[0]
            date_upload.append(upload)
            try:
                source = imgRoot.xpath(
                  "//aside[@id='sidebar']//div//p/a[@href]/@href")[1]
            except IndexError:
                source = 'No Source Given'
            img_source.append(source)
            thumbs_alt = imgRoot.xpath(
              "//div[@class='thumbable']//div[@class='thumb_mini_container']//span/@alt")[0]
            thumbs_alt = thumbs_alt.split(', ')
            thumbs_alt[0] = re.sub('\sup', '',thumbs_alt[0])
            thumbs_alt[1] = re.sub('\sdown', '',thumbs_alt[1])
            pos_votes.append(thumbs_alt[0])
            neg_votes.append(thumbs_alt[1])
            tag = imgRoot.xpath(
              "//aside[@id='sidebar']//div//p[@id='tag_list']//@data-tag")
            delim = '|'
            tags = ''
            for t in tag:
                tags = tags + str(t) + delim 
            kym_tags.append(tags)
            edits =str(
              'https://knowyourmeme.com'
              +imgRoot.xpath("//aside[@id='sidebar']//div[@class='tc']//a[contains(@href, 'edits')]/@href")[0])
            img_edits_url.append(edits)
            alt =  imgRoot.xpath("*//div[@class='thumbable']//img[@alt]/@alt")[0]
            alt_txt.append(alt)

            author_tag = imgRoot.xpath("//div[@id='author_info']//div//h6/a/text()")
            author.append(author_tag)

            # Output Image Files To Created Meme Directory
            os.makedirs(f'./GCV_FuncTestData/{img_loc}', exist_ok=True)
            urllib.request.urlretrieve(img, f'./GCV_FuncTestData/{img_loc}/{img_file}')

            # Build dataframe of metadata
            # Jeff says "short columns sooner, long columns later... with the more important columns prioritized sooner."
        metadata_df = pd.DataFrame({
            'img_ID': img_IDs, 
            'meme_name': img_locs,
            'date_upload': date_upload,
            'kym_tags': kym_tags,
            'pos_votes': pos_votes,
            'neg_votes': neg_votes,
            'img_source': img_source,
            'views': views,
            'views_today': views_today,
            'img_edits_url': img_edits_url,
            'author': author,
            'alt_txt': alt_txt,
            'img_url': url_suffixes,
            'lrg_img_url': lrg_img
        })

        # Output a metadata csv with csv name containing the date captured.
        metadata_df.to_csv(
            f'./GCV_FuncTestData/{str(name)}-meme/{name}_KYMmetadata_{dateMDY}.csv'
          , index=False)
    except:
        traceback.print_exc(file=out)
    out.write('Metadata file completed.\n')
    #print('Metadata file completed.')
    out.write('KYM_GALLERY_PULL Function Completed.\n\n')
    #print('KYM_GALLERY_PULL Function Completed.\n\n')
    # Close Output File
    out.close()

# %%
kym_gallery_pull('loss')
# Out:
# KYM_GALLERY_PULL Function Initiated: 12/03/2021, 00:00:00...
# Retrieving img at href /photos/2247003-loss
# https://knowyourmeme.com/memes/loss/photos/2247003-loss
# Retrieving Image 002_247_003_774.png
# Retrieving img at href /photos/2231456-loss
# https://knowyourmeme.com/memes/loss/photos/2231456-loss
# Retrieving Image 002_231_456_f6d.jpg
# Retrieving img at href /photos/2228646-loss
# https://knowyourmeme.com/memes/loss/photos/2228646-loss
# Retrieving Image 002_228_646_313.jpg
# Retrieving img at href /photos/2212542-loss
# https://knowyourmeme.com/memes/loss/photos/2212542-loss
# Retrieving Image 002_212_542_769.jpg
# Retrieving img at href /photos/2146625-loss
# https://knowyourmeme.com/memes/loss/photos/2146625-loss
# Retrieving Image 002_146_625_a13.png
# Retrieving img at href /photos/2111385-loss
# https://knowyourmeme.com/memes/loss/photos/2111385-loss
# Retrieving Image 002_111_385_d6e.jpg
# Retrieving img at href /photos/2090511-loss
# https://knowyourmeme.com/memes/loss/photos/2090511-loss
# Retrieving Image 002_090_511_8a3.jpg
# Retrieving img at href /photos/2085402-loss
# https://knowyourmeme.com/memes/loss/photos/2085402-loss
# Retrieving Image 002_085_402_dd5.jpg
# Retrieving img at href /photos/2084397-loss
# https://knowyourmeme.com/memes/loss/photos/2084397-loss
# Retrieving Image 002_084_397_960
# Retrieving img at href /photos/2032360-loss
# https://knowyourmeme.com/memes/loss/photos/2032360-loss
# Retrieving Image 002_032_360_5c1.jpg
# Retrieving img at href /photos/2032064-loss
# https://knowyourmeme.com/memes/loss/photos/2032064-loss
# Retrieving Image 002_032_064_71a.png
# Retrieving img at href /photos/2031806-loss
# https://knowyourmeme.com/memes/loss/photos/2031806-loss
# Retrieving Image 002_031_806_240.png
# Retrieving img at href /photos/2027561-loss
# https://knowyourmeme.com/memes/loss/photos/2027561-loss
# Retrieving Image 002_027_561_5ca
# Retrieving img at href /photos/2002592-loss
# https://knowyourmeme.com/memes/loss/photos/2002592-loss
# Retrieving Image 002_002_592_bdf.png
# Retrieving img at href /photos/1999349-loss
# https://knowyourmeme.com/memes/loss/photos/1999349-loss
# Retrieving Image 001_999_349_a22.jpg
# Retrieving img at href /photos/1997311-loss
# https://knowyourmeme.com/memes/loss/photos/1997311-loss
# Retrieving Image 001_997_311_8d7.png
# Retrieving img at href /photos/1994843-loss
# https://knowyourmeme.com/memes/loss/photos/1994843-loss
# Retrieving Image 001_994_843_b6e.jpg
# Retrieving img at href /photos/1989942-loss
# https://knowyourmeme.com/memes/loss/photos/1989942-loss
# Retrieving Image 001_989_942_cdb.jpg
# Retrieving img at href /photos/1964784-loss
# https://knowyourmeme.com/memes/loss/photos/1964784-loss
# Retrieving Image 001_964_784_e61.png
# Retrieving img at href /photos/1963979-loss
# https://knowyourmeme.com/memes/loss/photos/1963979-loss
# Retrieving Image 001_963_979_11c.jpg
# Retrieving img at href /photos/1963430-loss
# https://knowyourmeme.com/memes/loss/photos/1963430-loss
# Retrieving Image 001_963_430_127.jpg
# Retrieving img at href /photos/1920881-loss
# https://knowyourmeme.com/memes/loss/photos/1920881-loss
# Retrieving Image 001_920_881_907.png
# Retrieving img at href /photos/1889501-loss
# https://knowyourmeme.com/memes/loss/photos/1889501-loss
# Retrieving Image 001_889_501_21f.jpg
# Retrieving img at href /photos/1886508-loss
# https://knowyourmeme.com/memes/loss/photos/1886508-loss
# Retrieving Image 001_886_508_013.jpg
# Retrieving img at href /photos/1879361-loss
# https://knowyourmeme.com/memes/loss/photos/1879361-loss
# Retrieving Image 001_879_361_d6e
# Retrieving img at href /photos/1873896-loss
# https://knowyourmeme.com/memes/loss/photos/1873896-loss
# Retrieving Image 001_873_896_b4b.png
# Retrieving img at href /photos/1865557-loss
# https://knowyourmeme.com/memes/loss/photos/1865557-loss
# Retrieving Image 001_865_557_28f.jpg
# Retrieving img at href /photos/1861239-loss
# https://knowyourmeme.com/memes/loss/photos/1861239-loss
# Retrieving Image 001_861_239_464.png
# Retrieving img at href /photos/1858347-loss
# https://knowyourmeme.com/memes/loss/photos/1858347-loss
# Retrieving Image 001_858_347_d31.jpg
# Retrieving img at href /photos/1858342-loss
# https://knowyourmeme.com/memes/loss/photos/1858342-loss
# Retrieving Image 001_858_342_5da.jpg
# Retrieving img at href /photos/1855066-loss
# https://knowyourmeme.com/memes/loss/photos/1855066-loss
# Retrieving Image 001_855_066_39b.jpg
# Retrieving img at href /photos/1850121-loss
# https://knowyourmeme.com/memes/loss/photos/1850121-loss
# Retrieving Image 001_850_121_bcf.jpg
# Retrieving img at href /photos/1848070-loss
# https://knowyourmeme.com/memes/loss/photos/1848070-loss
# Retrieving Image 001_848_070_c03.png
# Retrieving img at href /photos/1846935-loss
# https://knowyourmeme.com/memes/loss/photos/1846935-loss
# Retrieving Image 001_846_935_b11.jpg
# Retrieving img at href /photos/1844640-loss
# https://knowyourmeme.com/memes/loss/photos/1844640-loss
# Retrieving Image 001_844_640_cb4.png
# Retrieving img at href /photos/1774982-loss
# https://knowyourmeme.com/memes/loss/photos/1774982-loss
# Retrieving Image 001_774_982_4d7
# Retrieving img at href /photos/1768579-loss
# https://knowyourmeme.com/memes/loss/photos/1768579-loss
# Retrieving Image 001_768_579_bb5.png
# Retrieving img at href /photos/1764263-loss
# https://knowyourmeme.com/memes/loss/photos/1764263-loss
# Retrieving Image 001_764_263_024.png
# Retrieving img at href /photos/1760751-loss
# https://knowyourmeme.com/memes/loss/photos/1760751-loss
# Retrieving Image 001_760_751_02d.png
# Retrieving img at href /photos/1760588-loss
# https://knowyourmeme.com/memes/loss/photos/1760588-loss
# Retrieving Image 001_760_588_f05.png
# Retrieving img at href /photos/1757034-loss
# https://knowyourmeme.com/memes/loss/photos/1757034-loss
# Retrieving Image 001_757_034_b9f.jpg
# Retrieving img at href /photos/1756667-loss
# https://knowyourmeme.com/memes/loss/photos/1756667-loss
# Retrieving Image 001_756_667_fb0.gif
# Retrieving img at href /photos/1753256-loss
# https://knowyourmeme.com/memes/loss/photos/1753256-loss
# Retrieving Image 001_753_256_376.png
# Retrieving img at href /photos/1739308-loss
# https://knowyourmeme.com/memes/loss/photos/1739308-loss
# Retrieving Image 001_739_308_6f0.jpg
# Retrieving img at href /photos/1738371-loss
# https://knowyourmeme.com/memes/loss/photos/1738371-loss
# Retrieving Image 001_738_371_443.jpg
# Retrieving img at href /photos/1724375-loss
# https://knowyourmeme.com/memes/loss/photos/1724375-loss
# Retrieving Image 001_724_375_68f.jpg
# Retrieving img at href /photos/1722219-loss
# https://knowyourmeme.com/memes/loss/photos/1722219-loss
# Retrieving Image 001_722_219_f36
# Retrieving img at href /photos/1711524-loss
# https://knowyourmeme.com/memes/loss/photos/1711524-loss
# Retrieving Image 001_711_524_9db.jpg
# Retrieving img at href /photos/1695322-loss
# https://knowyourmeme.com/memes/loss/photos/1695322-loss
# Retrieving Image 001_695_322_347.png
# Retrieving img at href /photos/1680150-loss
# https://knowyourmeme.com/memes/loss/photos/1680150-loss
# Retrieving Image 001_680_150_a1b.jpg
# Retrieving img at href /photos/1676795-loss
# https://knowyourmeme.com/memes/loss/photos/1676795-loss
# Retrieving Image 001_676_795_eb9.png
# Retrieving img at href /photos/1663893-loss
# https://knowyourmeme.com/memes/loss/photos/1663893-loss
# Retrieving Image 001_663_893_585.png
# Retrieving img at href /photos/1652134-loss
# https://knowyourmeme.com/memes/loss/photos/1652134-loss
# Retrieving Image 001_652_134_d94.png
# Retrieving img at href /photos/1644981-loss
# https://knowyourmeme.com/memes/loss/photos/1644981-loss
# Retrieving Image 001_644_981_172.jpg
# Retrieving img at href /photos/1617718-loss
# https://knowyourmeme.com/memes/loss/photos/1617718-loss
# Retrieving Image 001_617_718_5dd.jpg
# Retrieving img at href /photos/1617508-loss
# https://knowyourmeme.com/memes/loss/photos/1617508-loss
# Retrieving Image 001_617_508_704.png
# Retrieving img at href /photos/1577230-loss
# https://knowyourmeme.com/memes/loss/photos/1577230-loss
# Retrieving Image 001_577_230_7ab.png
# Retrieving img at href /photos/1576857-loss
# https://knowyourmeme.com/memes/loss/photos/1576857-loss
# Retrieving Image 001_576_857_ac6.gif
# Retrieving img at href /photos/1573605-loss
# https://knowyourmeme.com/memes/loss/photos/1573605-loss
# Retrieving Image 001_573_605_3f0.png
# Retrieving img at href /photos/1550449-loss
# https://knowyourmeme.com/memes/loss/photos/1550449-loss
# Retrieving Image 001_550_449_2f2
# Retrieving img at href /photos/1549524-loss
# https://knowyourmeme.com/memes/loss/photos/1549524-loss
# Retrieving Image 001_549_524_3f8.jpg
# Retrieving img at href /photos/1518836-loss
# https://knowyourmeme.com/memes/loss/photos/1518836-loss
# Retrieving Image 001_518_836_5e0.pnj
# Retrieving img at href /photos/1513877-loss
# https://knowyourmeme.com/memes/loss/photos/1513877-loss
# Retrieving Image 001_513_877_3fb.jpg
# Retrieving img at href /photos/1513304-loss
# https://knowyourmeme.com/memes/loss/photos/1513304-loss
# Retrieving Image 001_513_304_0ff.jpg
# Retrieving img at href /photos/1511635-loss
# https://knowyourmeme.com/memes/loss/photos/1511635-loss
# Retrieving Image 001_511_635_694.pnj
# Retrieving img at href /photos/1511121-loss
# https://knowyourmeme.com/memes/loss/photos/1511121-loss
# Retrieving Image 001_511_121_694.png
# Retrieving img at href /photos/1511120-loss
# https://knowyourmeme.com/memes/loss/photos/1511120-loss
# Retrieving Image 001_511_120_5d5.png
# Retrieving img at href /photos/1510406-loss
# https://knowyourmeme.com/memes/loss/photos/1510406-loss
# Retrieving Image 001_510_406_b97.png
# Retrieving img at href /photos/1506692-loss
# https://knowyourmeme.com/memes/loss/photos/1506692-loss
# Retrieving Image 001_506_692_8fe.jpg
# Retrieving img at href /photos/1502070-loss
# https://knowyourmeme.com/memes/loss/photos/1502070-loss
# Retrieving Image 001_502_070_574.png
# Retrieving img at href /photos/1500829-loss
# https://knowyourmeme.com/memes/loss/photos/1500829-loss
# Retrieving Image 001_500_829_c7f.jpg
# Retrieving img at href /photos/1498467-loss
# https://knowyourmeme.com/memes/loss/photos/1498467-loss
# Retrieving Image 001_498_467_e3b.jpg
# Retrieving img at href /photos/1498187-loss
# https://knowyourmeme.com/memes/loss/photos/1498187-loss
# Retrieving Image 001_498_187_4fe.pnj
# Retrieving img at href /photos/1495474-loss
# https://knowyourmeme.com/memes/loss/photos/1495474-loss
# Retrieving Image 001_495_474_9b3.png
# Retrieving img at href /photos/1494681-loss
# https://knowyourmeme.com/memes/loss/photos/1494681-loss
# Retrieving Image 001_494_681_afd.jpeg
# Retrieving img at href /photos/1492612-loss
# https://knowyourmeme.com/memes/loss/photos/1492612-loss
# Retrieving Image 001_492_612_980.png
# Retrieving img at href /photos/1492518-loss
# https://knowyourmeme.com/memes/loss/photos/1492518-loss
# Retrieving Image 001_492_518_d5e.png
# Retrieving img at href /photos/1491758-loss
# https://knowyourmeme.com/memes/loss/photos/1491758-loss
# Retrieving Image 001_491_758_26c.jpg
# Retrieving img at href /photos/1489370-loss
# https://knowyourmeme.com/memes/loss/photos/1489370-loss
# Retrieving Image 001_489_370_4b6.png
# Retrieving img at href /photos/1488319-loss
# https://knowyourmeme.com/memes/loss/photos/1488319-loss
# Retrieving Image 001_488_319_8ef.png
# Retrieving img at href /photos/1487923-loss
# https://knowyourmeme.com/memes/loss/photos/1487923-loss
# Retrieving Image 001_487_923_f0b.jpg
# Retrieving img at href /photos/1486937-loss
# https://knowyourmeme.com/memes/loss/photos/1486937-loss
# Retrieving Image 001_486_937_644.jpg
# Retrieving img at href /photos/1485949-loss
# https://knowyourmeme.com/memes/loss/photos/1485949-loss
# Retrieving Image 001_485_949_ff9.jpg
# Retrieving img at href /photos/1483595-loss
# https://knowyourmeme.com/memes/loss/photos/1483595-loss
# Retrieving Image 001_483_595_19c.png
# Retrieving img at href /photos/1483492-loss
# https://knowyourmeme.com/memes/loss/photos/1483492-loss
# Retrieving Image 001_483_492_e40.png
# Retrieving img at href /photos/1483150-loss
# https://knowyourmeme.com/memes/loss/photos/1483150-loss
# Retrieving Image 001_483_150_584.png
# Retrieving img at href /photos/1481462-loss
# https://knowyourmeme.com/memes/loss/photos/1481462-loss
# Retrieving Image 001_481_462_022.png
# Retrieving img at href /photos/1481182-loss
# https://knowyourmeme.com/memes/loss/photos/1481182-loss
# Retrieving Image 001_481_182_b39.jpg
# Retrieving img at href /photos/1480519-loss
# https://knowyourmeme.com/memes/loss/photos/1480519-loss
# Retrieving Image 001_480_519_8b9.png
# Retrieving img at href /photos/1479007-loss
# https://knowyourmeme.com/memes/loss/photos/1479007-loss
# Retrieving Image 001_479_007_fb5.jpg
# Retrieving img at href /photos/1478857-loss
# https://knowyourmeme.com/memes/loss/photos/1478857-loss
# Retrieving Image 001_478_857_dfd.jpg
# Retrieving img at href /photos/1476454-loss
# https://knowyourmeme.com/memes/loss/photos/1476454-loss
# Retrieving Image 001_476_454_d51.pnj
# Retrieving img at href /photos/1475558-loss
# https://knowyourmeme.com/memes/loss/photos/1475558-loss
# Retrieving Image 001_475_558_a38.png
# Retrieving img at href /photos/1473267-loss
# https://knowyourmeme.com/memes/loss/photos/1473267-loss
# Retrieving Image 001_473_267_b63.png
# Retrieving img at href /photos/1472731-loss
# https://knowyourmeme.com/memes/loss/photos/1472731-loss
# Retrieving Image 001_472_731_231.png
# Retrieving img at href /photos/1472427-loss
# https://knowyourmeme.com/memes/loss/photos/1472427-loss
# Retrieving Image 001_472_427_1b2.jpeg
# Retrieving img at href /photos/1471760-loss
# https://knowyourmeme.com/memes/loss/photos/1471760-loss
# Retrieving Image 001_471_760_e01.png
# Retrieving img at href /photos/1471510-loss
# https://knowyourmeme.com/memes/loss/photos/1471510-loss
# Retrieving Image 001_471_510_f04.jpg
# Retrieving img at href /photos/1471167-loss
# https://knowyourmeme.com/memes/loss/photos/1471167-loss
# Retrieving Image 001_471_167_43b.jpg
# Retrieving img at href /photos/1470825-loss
# https://knowyourmeme.com/memes/loss/photos/1470825-loss
# Retrieving Image 001_470_825_2ca.png
# Retrieving img at href /photos/1470262-loss
# https://knowyourmeme.com/memes/loss/photos/1470262-loss
# Retrieving Image 001_470_262_8bb.png
# Retrieving img at href /photos/1463758-loss
# https://knowyourmeme.com/memes/loss/photos/1463758-loss
# Retrieving Image 001_463_758_a14.png
# Retrieving img at href /photos/1462898-loss
# https://knowyourmeme.com/memes/loss/photos/1462898-loss
# Retrieving Image 001_462_898_6da.jpg
# Retrieving img at href /photos/1460482-loss
# https://knowyourmeme.com/memes/loss/photos/1460482-loss
# Retrieving Image 001_460_482_57e.gif
# Retrieving img at href /photos/1456550-loss
# https://knowyourmeme.com/memes/loss/photos/1456550-loss
# Retrieving Image 001_456_550_e97.png
# Retrieving img at href /photos/1455893-loss
# https://knowyourmeme.com/memes/loss/photos/1455893-loss
# Retrieving Image 001_455_893_d4c.jpg
# Retrieving img at href /photos/1454167-loss
# https://knowyourmeme.com/memes/loss/photos/1454167-loss
# Retrieving Image 001_454_167_875.gif
# Retrieving img at href /photos/1451365-loss
# https://knowyourmeme.com/memes/loss/photos/1451365-loss
# Retrieving Image 001_451_365_e70.png
# Retrieving img at href /photos/1448000-loss
# https://knowyourmeme.com/memes/loss/photos/1448000-loss
# Retrieving Image 001_448_000_649.jpg
# Retrieving img at href /photos/1446272-loss
# https://knowyourmeme.com/memes/loss/photos/1446272-loss
# Retrieving Image 001_446_272_1f2.jpeg
# Retrieving img at href /photos/1444083-loss
# https://knowyourmeme.com/memes/loss/photos/1444083-loss
# Retrieving Image 001_444_083_0b5.jpg
# Retrieving img at href /photos/1443741-loss
# https://knowyourmeme.com/memes/loss/photos/1443741-loss
# Retrieving Image 001_443_741_fd2.jpg
# Retrieving img at href /photos/1438290-loss
# https://knowyourmeme.com/memes/loss/photos/1438290-loss
# Retrieving Image 001_438_290_e78.png
# Retrieving img at href /photos/1437994-loss
# https://knowyourmeme.com/memes/loss/photos/1437994-loss
# Retrieving Image 001_437_994_19d.jpg
# Retrieving img at href /photos/1431571-loss
# https://knowyourmeme.com/memes/loss/photos/1431571-loss
# Retrieving Image 001_431_571_3af.png
# Retrieving img at href /photos/1430763-loss
# https://knowyourmeme.com/memes/loss/photos/1430763-loss
# Retrieving Image 001_430_763_2ec.jpg
# Retrieving img at href /photos/1429919-loss
# https://knowyourmeme.com/memes/loss/photos/1429919-loss
# Retrieving Image 001_429_919_2e8.jpg
# Retrieving img at href /photos/1429436-loss
# https://knowyourmeme.com/memes/loss/photos/1429436-loss
# Retrieving Image 001_429_436_79d.png
# Retrieving img at href /photos/1429337-loss
# https://knowyourmeme.com/memes/loss/photos/1429337-loss
# Retrieving Image 001_429_337_467.jpg
# Retrieving img at href /photos/1428638-loss
# https://knowyourmeme.com/memes/loss/photos/1428638-loss
# Retrieving Image 001_428_638_e36.png
# Retrieving img at href /photos/1425436-loss
# https://knowyourmeme.com/memes/loss/photos/1425436-loss
# Retrieving Image 001_425_436_a0e.png
# Retrieving img at href /photos/1425199-loss
# https://knowyourmeme.com/memes/loss/photos/1425199-loss
# Retrieving Image 001_425_199_e10.png
# Retrieving img at href /photos/1424983-loss
# https://knowyourmeme.com/memes/loss/photos/1424983-loss
# Retrieving Image 001_424_983_c8d.png
# Retrieving img at href /photos/1422835-loss
# https://knowyourmeme.com/memes/loss/photos/1422835-loss
# Retrieving Image 001_422_835_9b7.png
# Retrieving img at href /photos/1421925-loss
# https://knowyourmeme.com/memes/loss/photos/1421925-loss
# Retrieving Image 001_421_925_a82.png
# Retrieving img at href /photos/1421710-loss
# https://knowyourmeme.com/memes/loss/photos/1421710-loss
# Retrieving Image 001_421_710_205.jpg
# Retrieving img at href /photos/1417181-loss
# https://knowyourmeme.com/memes/loss/photos/1417181-loss
# Retrieving Image 001_417_181_faa.jpeg
# Retrieving img at href /photos/1416721-loss
# https://knowyourmeme.com/memes/loss/photos/1416721-loss
# Retrieving Image 001_416_721_c3d.png
# Retrieving img at href /photos/1415782-loss
# https://knowyourmeme.com/memes/loss/photos/1415782-loss
# Retrieving Image 001_415_782_eff.jpg
# Retrieving img at href /photos/1415018-loss
# https://knowyourmeme.com/memes/loss/photos/1415018-loss
# Retrieving Image 001_415_018_bc7.gif
# Retrieving img at href /photos/1414129-loss
# https://knowyourmeme.com/memes/loss/photos/1414129-loss
# Retrieving Image 001_414_129_819.jpg
# Retrieving img at href /photos/1411992-loss
# https://knowyourmeme.com/memes/loss/photos/1411992-loss
# Retrieving Image 001_411_992_54a.png
# Retrieving img at href /photos/1411693-loss
# https://knowyourmeme.com/memes/loss/photos/1411693-loss
# Retrieving Image 001_411_693_823.png
# Retrieving img at href /photos/1411485-loss
# https://knowyourmeme.com/memes/loss/photos/1411485-loss
# Retrieving Image 001_411_485_fcc.jpg
# Retrieving img at href /photos/1411087-loss
# https://knowyourmeme.com/memes/loss/photos/1411087-loss
# Retrieving Image 001_411_087_cb8.png
# Retrieving img at href /photos/1410940-loss
# https://knowyourmeme.com/memes/loss/photos/1410940-loss
# Retrieving Image 001_410_940_ad9.png
# Retrieving img at href /photos/1410628-loss
# https://knowyourmeme.com/memes/loss/photos/1410628-loss
# Retrieving Image 001_410_628_37c.jpg
# Retrieving img at href /photos/1409918-loss
# https://knowyourmeme.com/memes/loss/photos/1409918-loss
# Retrieving Image 001_409_918_cbe.jpg
# Retrieving img at href /photos/1409379-loss
# https://knowyourmeme.com/memes/loss/photos/1409379-loss
# Retrieving Image 001_409_379_416.png
# Retrieving img at href /photos/1409150-loss
# https://knowyourmeme.com/memes/loss/photos/1409150-loss
# Retrieving Image 001_409_150_9b7.png
# Retrieving img at href /photos/1409121-loss
# https://knowyourmeme.com/memes/loss/photos/1409121-loss
# Retrieving Image 001_409_121_dc8.png
# Retrieving img at href /photos/1408985-loss
# https://knowyourmeme.com/memes/loss/photos/1408985-loss
# Retrieving Image 001_408_985_629.png
# Retrieving img at href /photos/1408626-loss
# https://knowyourmeme.com/memes/loss/photos/1408626-loss
# Retrieving Image 001_408_626_9b8.jpg
# Retrieving img at href /photos/1408408-loss
# https://knowyourmeme.com/memes/loss/photos/1408408-loss
# Retrieving Image 001_408_408_381.jpg
# Retrieving img at href /photos/1407789-loss
# https://knowyourmeme.com/memes/loss/photos/1407789-loss
# Retrieving Image 001_407_789_5a4.jpg
# Retrieving img at href /photos/1407059-loss
# https://knowyourmeme.com/memes/loss/photos/1407059-loss
# Retrieving Image 001_407_059_02c.png
# Retrieving img at href /photos/1406921-loss
# https://knowyourmeme.com/memes/loss/photos/1406921-loss
# Retrieving Image 001_406_921_654.jpeg
# Retrieving img at href /photos/1406202-loss
# https://knowyourmeme.com/memes/loss/photos/1406202-loss
# Retrieving Image 001_406_202_fac.jpeg
# Retrieving img at href /photos/1405252-loss
# https://knowyourmeme.com/memes/loss/photos/1405252-loss
# Retrieving Image 001_405_252_74c.png
# Retrieving img at href /photos/1404457-loss
# https://knowyourmeme.com/memes/loss/photos/1404457-loss
# Retrieving Image 001_404_457_5e0.png
# Retrieving img at href /photos/1404358-loss
# https://knowyourmeme.com/memes/loss/photos/1404358-loss
# Retrieving Image 001_404_358_516.jpg
# Retrieving img at href /photos/1403809-loss
# https://knowyourmeme.com/memes/loss/photos/1403809-loss
# Retrieving Image 001_403_809_24e.jpg
# Retrieving img at href /photos/1402693-loss
# https://knowyourmeme.com/memes/loss/photos/1402693-loss
# Retrieving Image 001_402_693_b2a.jpg
# Retrieving img at href /photos/1402686-loss
# https://knowyourmeme.com/memes/loss/photos/1402686-loss
# Retrieving Image 001_402_686_dce.jpg
# Retrieving img at href /photos/1402121-loss
# https://knowyourmeme.com/memes/loss/photos/1402121-loss
# Retrieving Image 001_402_121_c1d.jpg
# Retrieving img at href /photos/1401963-loss
# https://knowyourmeme.com/memes/loss/photos/1401963-loss
# Retrieving Image 001_401_963_f7c.jpg
# Retrieving img at href /photos/1401819-loss
# https://knowyourmeme.com/memes/loss/photos/1401819-loss
# Retrieving Image 001_401_819_560.jpeg
# Retrieving img at href /photos/1401398-loss
# https://knowyourmeme.com/memes/loss/photos/1401398-loss
# Retrieving Image 001_401_398_6f5.png
# Retrieving img at href /photos/1401011-loss
# https://knowyourmeme.com/memes/loss/photos/1401011-loss
# Retrieving Image 001_401_011_458.png
# Retrieving img at href /photos/1400969-loss
# https://knowyourmeme.com/memes/loss/photos/1400969-loss
# Retrieving Image 001_400_969_d31.jpg
# Retrieving img at href /photos/1399600-loss
# https://knowyourmeme.com/memes/loss/photos/1399600-loss
# Retrieving Image 001_399_600_372.png
# Retrieving img at href /photos/1398840-loss
# https://knowyourmeme.com/memes/loss/photos/1398840-loss
# Retrieving Image 001_398_840_1c4.jpg
# Retrieving img at href /photos/1398725-loss
# https://knowyourmeme.com/memes/loss/photos/1398725-loss
# Retrieving Image 001_398_725_d1f.png
# Retrieving img at href /photos/1398707-loss
# https://knowyourmeme.com/memes/loss/photos/1398707-loss
# Retrieving Image 001_398_707_2b5.png
# Retrieving img at href /photos/1398638-loss
# https://knowyourmeme.com/memes/loss/photos/1398638-loss
# Retrieving Image 001_398_638_051.png
# Retrieving img at href /photos/1398049-loss
# https://knowyourmeme.com/memes/loss/photos/1398049-loss
# Retrieving Image 001_398_049_556.jpg
# Retrieving img at href /photos/1397804-loss
# https://knowyourmeme.com/memes/loss/photos/1397804-loss
# Retrieving Image 001_397_804_3b1.png
# Retrieving img at href /photos/1397759-loss
# https://knowyourmeme.com/memes/loss/photos/1397759-loss
# Retrieving Image 001_397_759_892.png
# Retrieving img at href /photos/1397255-loss
# https://knowyourmeme.com/memes/loss/photos/1397255-loss
# Retrieving Image 001_397_255_d25.jpg
# Retrieving img at href /photos/1396664-loss
# https://knowyourmeme.com/memes/loss/photos/1396664-loss
# Retrieving Image 001_396_664_b3c.png
# Retrieving img at href /photos/1396375-loss
# https://knowyourmeme.com/memes/loss/photos/1396375-loss
# Retrieving Image 001_396_375_602.jpg
# Retrieving img at href /photos/1395988-loss
# https://knowyourmeme.com/memes/loss/photos/1395988-loss
# Retrieving Image 001_395_988_ef9.jpg
# Retrieving img at href /photos/1395984-loss
# https://knowyourmeme.com/memes/loss/photos/1395984-loss
# Retrieving Image 001_395_984_ba7.jpg
# Retrieving img at href /photos/1395055-loss
# https://knowyourmeme.com/memes/loss/photos/1395055-loss
# Retrieving Image 001_395_055_845.png
# Retrieving img at href /photos/1395051-loss
# https://knowyourmeme.com/memes/loss/photos/1395051-loss
# Retrieving Image 001_395_051_caa.jpg
# Retrieving img at href /photos/1393402-loss
# https://knowyourmeme.com/memes/loss/photos/1393402-loss
# Retrieving Image 001_393_402_915.png
# Retrieving img at href /photos/1392344-loss
# https://knowyourmeme.com/memes/loss/photos/1392344-loss
# Retrieving Image 001_392_344_569.png
# Retrieving img at href /photos/1392289-loss
# https://knowyourmeme.com/memes/loss/photos/1392289-loss
# Retrieving Image 001_392_289_ec4.png
# Retrieving img at href /photos/1392263-loss
# https://knowyourmeme.com/memes/loss/photos/1392263-loss
# Retrieving Image 001_392_263_7ab.png
# Retrieving img at href /photos/1391717-loss
# https://knowyourmeme.com/memes/loss/photos/1391717-loss
# Retrieving Image 001_391_717_fd4.png
# Retrieving img at href /photos/1391587-loss
# https://knowyourmeme.com/memes/loss/photos/1391587-loss
# Retrieving Image 001_391_587_292.jpg
# Retrieving img at href /photos/1391363-loss
# https://knowyourmeme.com/memes/loss/photos/1391363-loss
# Retrieving Image 001_391_363_fb3.jpg
# Retrieving img at href /photos/1391254-loss
# https://knowyourmeme.com/memes/loss/photos/1391254-loss
# Retrieving Image 001_391_254_6e5.jpg
# Retrieving img at href /photos/1391115-loss
# https://knowyourmeme.com/memes/loss/photos/1391115-loss
# Retrieving Image 001_391_115_832.png
# Retrieving img at href /photos/1390756-loss
# https://knowyourmeme.com/memes/loss/photos/1390756-loss
# Retrieving Image 001_390_756_bc5.jpg
# Retrieving img at href /photos/1390571-loss
# https://knowyourmeme.com/memes/loss/photos/1390571-loss
# Retrieving Image 001_390_571_876.jpg
# Retrieving img at href /photos/1390458-loss
# https://knowyourmeme.com/memes/loss/photos/1390458-loss
# Retrieving Image 001_390_458_5c4.png
# Retrieving img at href /photos/1390086-loss
# https://knowyourmeme.com/memes/loss/photos/1390086-loss
# Retrieving Image 001_390_086_040.jpeg
# Retrieving img at href /photos/1389708-loss
# https://knowyourmeme.com/memes/loss/photos/1389708-loss
# Retrieving Image 001_389_708_aed.png
# Retrieving img at href /photos/1389583-loss
# https://knowyourmeme.com/memes/loss/photos/1389583-loss
# Retrieving Image 001_389_583_c83.png
# Retrieving img at href /photos/1389072-loss
# https://knowyourmeme.com/memes/loss/photos/1389072-loss
# Retrieving Image 001_389_072_0dd.jpg
# Retrieving img at href /photos/1389012-loss
# https://knowyourmeme.com/memes/loss/photos/1389012-loss
# Retrieving Image 001_389_012_a85.jpg
# Retrieving img at href /photos/1389006-loss
# https://knowyourmeme.com/memes/loss/photos/1389006-loss
# Retrieving Image 001_389_006_b52.jpg
# Retrieving img at href /photos/1389003-loss
# https://knowyourmeme.com/memes/loss/photos/1389003-loss
# Retrieving Image 001_389_003_f1b.png
# Retrieving img at href /photos/1388897-loss
# https://knowyourmeme.com/memes/loss/photos/1388897-loss
# Retrieving Image 001_388_897_181.jpg
# Retrieving img at href /photos/1388821-loss
# https://knowyourmeme.com/memes/loss/photos/1388821-loss
# Retrieving Image 001_388_821_f24.png
# Retrieving img at href /photos/1388804-loss
# https://knowyourmeme.com/memes/loss/photos/1388804-loss
# Retrieving Image 001_388_804_6c2.jpg
# Retrieving img at href /photos/1388683-loss
# https://knowyourmeme.com/memes/loss/photos/1388683-loss
# Retrieving Image 001_388_683_da3.jpg
# Retrieving img at href /photos/1388618-loss
# https://knowyourmeme.com/memes/loss/photos/1388618-loss
# Retrieving Image 001_388_618_650.jpg
# Retrieving img at href /photos/1388606-loss
# https://knowyourmeme.com/memes/loss/photos/1388606-loss
# Retrieving Image 001_388_606_770.jpg
# Retrieving img at href /photos/1388332-loss
# https://knowyourmeme.com/memes/loss/photos/1388332-loss
# Retrieving Image 001_388_332_fe5.png
# Retrieving img at href /photos/1388302-loss
# https://knowyourmeme.com/memes/loss/photos/1388302-loss
# Retrieving Image 001_388_302_f2c.jpg
# Retrieving img at href /photos/1388179-loss
# https://knowyourmeme.com/memes/loss/photos/1388179-loss
# Retrieving Image 001_388_179_150.jpg
# Retrieving img at href /photos/1388072-loss
# https://knowyourmeme.com/memes/loss/photos/1388072-loss
# Retrieving Image 001_388_072_31a.jpg
# Retrieving img at href /photos/1387970-loss
# https://knowyourmeme.com/memes/loss/photos/1387970-loss
# Retrieving Image 001_387_970_02a.jpg
# Retrieving img at href /photos/1387899-loss
# https://knowyourmeme.com/memes/loss/photos/1387899-loss
# Retrieving Image 001_387_899_a5f.jpg
# Retrieving img at href /photos/1387674-loss
# https://knowyourmeme.com/memes/loss/photos/1387674-loss
# Retrieving Image 001_387_674_83c.png
# Retrieving img at href /photos/1387614-loss
# https://knowyourmeme.com/memes/loss/photos/1387614-loss
# Retrieving Image 001_387_614_bb5.png
# Retrieving img at href /photos/1387574-loss
# https://knowyourmeme.com/memes/loss/photos/1387574-loss
# Retrieving Image 001_387_574_e58
# Retrieving img at href /photos/1387236-loss
# https://knowyourmeme.com/memes/loss/photos/1387236-loss
# Retrieving Image 001_387_236_615.jpg
# Retrieving img at href /photos/1386624-loss
# https://knowyourmeme.com/memes/loss/photos/1386624-loss
# Retrieving Image 001_386_624_4b4.jpg
# Retrieving img at href /photos/1386613-loss
# https://knowyourmeme.com/memes/loss/photos/1386613-loss
# Retrieving Image 001_386_613_4e6.jpg
# Retrieving img at href /photos/1386578-loss
# https://knowyourmeme.com/memes/loss/photos/1386578-loss
# Retrieving Image 001_386_578_d89.png
# Retrieving img at href /photos/1386389-loss
# https://knowyourmeme.com/memes/loss/photos/1386389-loss
# Retrieving Image 001_386_389_1fa.png
# Retrieving img at href /photos/1386283-loss
# https://knowyourmeme.com/memes/loss/photos/1386283-loss
# Retrieving Image 001_386_283_304
# Retrieving img at href /photos/1385964-loss
# https://knowyourmeme.com/memes/loss/photos/1385964-loss
# Retrieving Image 001_385_964_c70.jpeg
# Retrieving img at href /photos/1385722-loss
# https://knowyourmeme.com/memes/loss/photos/1385722-loss
# Retrieving Image 001_385_722_143.png
# Retrieving img at href /photos/1385495-loss
# https://knowyourmeme.com/memes/loss/photos/1385495-loss
# Retrieving Image 001_385_495_066.png
# Retrieving img at href /photos/1385485-loss
# https://knowyourmeme.com/memes/loss/photos/1385485-loss
# Retrieving Image 001_385_485_d9d.jpg_orig
# Retrieving img at href /photos/1385433-loss
# https://knowyourmeme.com/memes/loss/photos/1385433-loss
# Retrieving Image 001_385_433_4c7.jpg
# Retrieving img at href /photos/1385380-loss
# https://knowyourmeme.com/memes/loss/photos/1385380-loss
# Retrieving Image 001_385_380_3a2.png
# Retrieving img at href /photos/1385279-loss
# https://knowyourmeme.com/memes/loss/photos/1385279-loss
# Retrieving Image 001_385_279_dc5.jpg
# Retrieving img at href /photos/1385149-loss
# https://knowyourmeme.com/memes/loss/photos/1385149-loss
# Retrieving Image 001_385_149_157.jpg
# Retrieving img at href /photos/1384934-loss
# https://knowyourmeme.com/memes/loss/photos/1384934-loss
# Retrieving Image 001_384_934_161.jpg
# Retrieving img at href /photos/1384803-loss
# https://knowyourmeme.com/memes/loss/photos/1384803-loss
# Retrieving Image 001_384_803_a33.png
# Retrieving img at href /photos/1384799-loss
# https://knowyourmeme.com/memes/loss/photos/1384799-loss
# Retrieving Image 001_384_799_6dd.png
# Retrieving img at href /photos/1384719-loss
# https://knowyourmeme.com/memes/loss/photos/1384719-loss
# Retrieving Image 001_384_719_dea.jpg
# Retrieving img at href /photos/1384707-loss
# https://knowyourmeme.com/memes/loss/photos/1384707-loss
# Retrieving Image 001_384_707_e2e.jpg
# Retrieving img at href /photos/1384601-loss
# https://knowyourmeme.com/memes/loss/photos/1384601-loss
# Retrieving Image 001_384_601_e1a.png
# Retrieving img at href /photos/1384381-loss
# https://knowyourmeme.com/memes/loss/photos/1384381-loss
# Retrieving Image 001_384_381_1e6.jpg_orig
# Retrieving img at href /photos/1384357-loss
# https://knowyourmeme.com/memes/loss/photos/1384357-loss
# Retrieving Image 001_384_357_f78.jpg
# Retrieving img at href /photos/1384338-loss
# https://knowyourmeme.com/memes/loss/photos/1384338-loss
# Retrieving Image 001_384_338_2ba.jpg
# Retrieving img at href /photos/1383867-loss
# https://knowyourmeme.com/memes/loss/photos/1383867-loss
# Retrieving Image 001_383_867_358.jpg
# Retrieving img at href /photos/1383863-loss
# https://knowyourmeme.com/memes/loss/photos/1383863-loss
# Retrieving Image 001_383_863_ccc.jpg
# Retrieving img at href /photos/1383847-loss
# https://knowyourmeme.com/memes/loss/photos/1383847-loss
# Retrieving Image 001_383_847_9fe.gif
# Retrieving img at href /photos/1383728-loss
# https://knowyourmeme.com/memes/loss/photos/1383728-loss
# Retrieving Image 001_383_728_73b.png
# Retrieving img at href /photos/1383720-loss
# https://knowyourmeme.com/memes/loss/photos/1383720-loss
# Retrieving Image 001_383_720_c9a.jpg
# Retrieving img at href /photos/1383715-loss
# https://knowyourmeme.com/memes/loss/photos/1383715-loss
# Retrieving Image 001_383_715_0ba.png
# Retrieving img at href /photos/1383652-loss
# https://knowyourmeme.com/memes/loss/photos/1383652-loss
# Retrieving Image 001_383_652_05e.png
# Retrieving img at href /photos/1383523-loss
# https://knowyourmeme.com/memes/loss/photos/1383523-loss
# Retrieving Image 001_383_523_8fb.jpg
# Retrieving img at href /photos/1383509-loss
# https://knowyourmeme.com/memes/loss/photos/1383509-loss
# Retrieving Image 001_383_509_fa9.jpg
# Retrieving img at href /photos/1383505-loss
# https://knowyourmeme.com/memes/loss/photos/1383505-loss
# Retrieving Image 001_383_505_184.jpg
# Retrieving img at href /photos/1383493-loss
# https://knowyourmeme.com/memes/loss/photos/1383493-loss
# Retrieving Image 001_383_493_7b3.png
# Retrieving img at href /photos/1383431-loss
# https://knowyourmeme.com/memes/loss/photos/1383431-loss
# Retrieving Image 001_383_431_11b.png
# Retrieving img at href /photos/1383382-loss
# https://knowyourmeme.com/memes/loss/photos/1383382-loss
# Retrieving Image 001_383_382_fe5.png
# Retrieving img at href /photos/1383380-loss
# https://knowyourmeme.com/memes/loss/photos/1383380-loss
# Retrieving Image 001_383_380_67b.jpg
# Retrieving img at href /photos/1383301-loss
# https://knowyourmeme.com/memes/loss/photos/1383301-loss
# Retrieving Image 001_383_301_c37.png
# Retrieving img at href /photos/1382983-loss
# https://knowyourmeme.com/memes/loss/photos/1382983-loss
# Retrieving Image 001_382_983_dd4.jpg
# Retrieving img at href /photos/1382941-loss
# https://knowyourmeme.com/memes/loss/photos/1382941-loss
# Retrieving Image 001_382_941_143.png
# Retrieving img at href /photos/1382841-loss
# https://knowyourmeme.com/memes/loss/photos/1382841-loss
# Retrieving Image 001_382_841_a55.png
# Retrieving img at href /photos/1382457-loss
# https://knowyourmeme.com/memes/loss/photos/1382457-loss
# Retrieving Image 001_382_457_8f4.jpg
# Retrieving img at href /photos/1382452-loss
# https://knowyourmeme.com/memes/loss/photos/1382452-loss
# Retrieving Image 001_382_452_5a9.png
# Retrieving img at href /photos/1381562-loss
# https://knowyourmeme.com/memes/loss/photos/1381562-loss
# Retrieving Image 001_381_562_147.png
# Retrieving img at href /photos/1381391-loss
# https://knowyourmeme.com/memes/loss/photos/1381391-loss
# Retrieving Image 001_381_391_4e9.png
# Retrieving img at href /photos/1381243-loss
# https://knowyourmeme.com/memes/loss/photos/1381243-loss
# Retrieving Image 001_381_243_4d7.jpg
# Retrieving img at href /photos/1381230-loss
# https://knowyourmeme.com/memes/loss/photos/1381230-loss
# Retrieving Image 001_381_230_098.jpg
# Retrieving img at href /photos/1381209-loss
# https://knowyourmeme.com/memes/loss/photos/1381209-loss
# Retrieving Image 001_381_209_7b8.jpg
# Retrieving img at href /photos/1381140-loss
# https://knowyourmeme.com/memes/loss/photos/1381140-loss
# Retrieving Image 001_381_140_296.png
# Retrieving img at href /photos/1381040-loss
# https://knowyourmeme.com/memes/loss/photos/1381040-loss
# Retrieving Image 001_381_040_743.png
# Retrieving img at href /photos/1380979-loss
# https://knowyourmeme.com/memes/loss/photos/1380979-loss
# Retrieving Image 001_380_979_bcf.png
# Retrieving img at href /photos/1380734-loss
# https://knowyourmeme.com/memes/loss/photos/1380734-loss
# Retrieving Image 001_380_734_7b2.jpg
# Retrieving img at href /photos/1380474-loss
# https://knowyourmeme.com/memes/loss/photos/1380474-loss
# Retrieving Image 001_380_474_bb7.jpg
# Retrieving img at href /photos/1380454-loss
# https://knowyourmeme.com/memes/loss/photos/1380454-loss
# Retrieving Image 001_380_454_3ff.jpg
# Retrieving img at href /photos/1380166-loss
# https://knowyourmeme.com/memes/loss/photos/1380166-loss
# Retrieving Image 001_380_166_029.png
# Retrieving img at href /photos/1380139-loss
# https://knowyourmeme.com/memes/loss/photos/1380139-loss
# Retrieving Image 001_380_139_12a.jpg
# Retrieving img at href /photos/1380043-loss
# https://knowyourmeme.com/memes/loss/photos/1380043-loss
# Retrieving Image 001_380_043_eb6.jpg
# Retrieving img at href /photos/1380042-loss
# https://knowyourmeme.com/memes/loss/photos/1380042-loss
# Retrieving Image 001_380_042_2e5.png
# Retrieving img at href /photos/1379903-loss
# https://knowyourmeme.com/memes/loss/photos/1379903-loss
# Retrieving Image 001_379_903_8e7.jpg
# Retrieving img at href /photos/1379899-loss
# https://knowyourmeme.com/memes/loss/photos/1379899-loss
# Retrieving Image 001_379_899_765.jpg
# Retrieving img at href /photos/1379769-loss
# https://knowyourmeme.com/memes/loss/photos/1379769-loss
# Retrieving Image 001_379_769_e21.jpg
# Retrieving img at href /photos/1379461-loss
# https://knowyourmeme.com/memes/loss/photos/1379461-loss
# Retrieving Image 001_379_461_a64.jpg
# Retrieving img at href /photos/1379458-loss
# https://knowyourmeme.com/memes/loss/photos/1379458-loss
# Retrieving Image 001_379_458_ce0.jpg
# Retrieving img at href /photos/1379457-loss
# https://knowyourmeme.com/memes/loss/photos/1379457-loss
# Retrieving Image 001_379_457_5a6.png
# Retrieving img at href /photos/1379428-loss
# https://knowyourmeme.com/memes/loss/photos/1379428-loss
# Retrieving Image 001_379_428_acd.jpg
# Retrieving img at href /photos/1379355-loss
# https://knowyourmeme.com/memes/loss/photos/1379355-loss
# Retrieving Image 001_379_355_be0.png
# Retrieving img at href /photos/1379134-loss
# https://knowyourmeme.com/memes/loss/photos/1379134-loss
# Retrieving Image 001_379_134_866.jpg
# Retrieving img at href /photos/1378931-loss
# https://knowyourmeme.com/memes/loss/photos/1378931-loss
# Retrieving Image 001_378_931_0dc.jpg
# Retrieving img at href /photos/1378892-loss
# https://knowyourmeme.com/memes/loss/photos/1378892-loss
# Retrieving Image 001_378_892_d6a.jpeg
# Retrieving img at href /photos/1378868-loss
# https://knowyourmeme.com/memes/loss/photos/1378868-loss
# Retrieving Image 001_378_868_0c6.png
# Retrieving img at href /photos/1378842-loss
# https://knowyourmeme.com/memes/loss/photos/1378842-loss
# Retrieving Image 001_378_842_b2d.jpg
# Retrieving img at href /photos/1378713-loss
# https://knowyourmeme.com/memes/loss/photos/1378713-loss
# Retrieving Image 001_378_713_06c.png
# Retrieving img at href /photos/1378693-loss
# https://knowyourmeme.com/memes/loss/photos/1378693-loss
# Retrieving Image 001_378_693_1a6.png
# Retrieving img at href /photos/1378533-loss
# https://knowyourmeme.com/memes/loss/photos/1378533-loss
# Retrieving Image 001_378_533_809.jpg
# Retrieving img at href /photos/1378532-loss
# https://knowyourmeme.com/memes/loss/photos/1378532-loss
# Retrieving Image 001_378_532_be6.jpg
# Retrieving img at href /photos/1378530-loss
# https://knowyourmeme.com/memes/loss/photos/1378530-loss
# Retrieving Image 001_378_530_6aa.jpg
# Retrieving img at href /photos/1378526-loss
# https://knowyourmeme.com/memes/loss/photos/1378526-loss
# Retrieving Image 001_378_526_4f1.jpg
# Retrieving img at href /photos/1378516-loss
# https://knowyourmeme.com/memes/loss/photos/1378516-loss
# Retrieving Image 001_378_516_492.png
# Retrieving img at href /photos/1378473-loss
# https://knowyourmeme.com/memes/loss/photos/1378473-loss
# Retrieving Image 001_378_473_46f.png
# Retrieving img at href /photos/1378471-loss
# https://knowyourmeme.com/memes/loss/photos/1378471-loss
# Retrieving Image 001_378_471_9d6.png
# Retrieving img at href /photos/1378451-loss
# https://knowyourmeme.com/memes/loss/photos/1378451-loss
# Retrieving Image 001_378_451_f6d.png
# Retrieving img at href /photos/1378448-loss
# https://knowyourmeme.com/memes/loss/photos/1378448-loss
# Retrieving Image 001_378_448_217.png
# Retrieving img at href /photos/1378394-loss
# https://knowyourmeme.com/memes/loss/photos/1378394-loss
# Retrieving Image 001_378_394_0fc.png
# Retrieving img at href /photos/1378384-loss
# https://knowyourmeme.com/memes/loss/photos/1378384-loss
# Retrieving Image 001_378_384_4a1.png
# Retrieving img at href /photos/1378353-loss
# https://knowyourmeme.com/memes/loss/photos/1378353-loss
# Retrieving Image 001_378_353_6a9.png
# Retrieving img at href /photos/1378337-loss
# https://knowyourmeme.com/memes/loss/photos/1378337-loss
# Retrieving Image 001_378_337_686.png
# Retrieving img at href /photos/1378326-loss
# https://knowyourmeme.com/memes/loss/photos/1378326-loss
# Retrieving Image 001_378_326_3f0.jpg
# Retrieving img at href /photos/1378325-loss
# https://knowyourmeme.com/memes/loss/photos/1378325-loss
# Retrieving Image 001_378_325_cbc.png
# Retrieving img at href /photos/1378324-loss
# https://knowyourmeme.com/memes/loss/photos/1378324-loss
# Retrieving Image 001_378_324_dbd.jpg
# Retrieving img at href /photos/1378322-loss
# https://knowyourmeme.com/memes/loss/photos/1378322-loss
# Retrieving Image 001_378_322_ac5.jpg
# Retrieving img at href /photos/1378316-loss
# https://knowyourmeme.com/memes/loss/photos/1378316-loss
# Retrieving Image 001_378_316_4a8.png
# Retrieving img at href /photos/1378306-loss
# https://knowyourmeme.com/memes/loss/photos/1378306-loss
# Retrieving Image 001_378_306_ed1.png
# Retrieving img at href /photos/1378275-loss
# https://knowyourmeme.com/memes/loss/photos/1378275-loss
# Retrieving Image 001_378_275_9eb.jpg
# Retrieving img at href /photos/1378274-loss
# https://knowyourmeme.com/memes/loss/photos/1378274-loss
# Retrieving Image 001_378_274_9c4.jpeg
# Retrieving img at href /photos/1378213-loss
# https://knowyourmeme.com/memes/loss/photos/1378213-loss
# Retrieving Image 001_378_213_814.jpg
# Retrieving img at href /photos/1378200-loss
# https://knowyourmeme.com/memes/loss/photos/1378200-loss
# Retrieving Image 001_378_200_1d1.png
# Retrieving img at href /photos/1378172-loss
# https://knowyourmeme.com/memes/loss/photos/1378172-loss
# Retrieving Image 001_378_172_f4b.jpg
# Retrieving img at href /photos/1377968-loss
# https://knowyourmeme.com/memes/loss/photos/1377968-loss
# Retrieving Image 001_377_968_00f.png
# Retrieving img at href /photos/1377800-loss
# https://knowyourmeme.com/memes/loss/photos/1377800-loss
# Retrieving Image 001_377_800_3fa.jpg
# Retrieving img at href /photos/1377760-loss
# https://knowyourmeme.com/memes/loss/photos/1377760-loss
# Retrieving Image 001_377_760_2b6.jpg
# Retrieving img at href /photos/1377742-loss
# https://knowyourmeme.com/memes/loss/photos/1377742-loss
# Retrieving Image 001_377_742_8e8.jpg
# Retrieving img at href /photos/1376815-loss
# https://knowyourmeme.com/memes/loss/photos/1376815-loss
# Retrieving Image 001_376_815_c68.png
# Retrieving img at href /photos/1376728-loss
# https://knowyourmeme.com/memes/loss/photos/1376728-loss
# Retrieving Image 001_376_728_56f.png
# Retrieving img at href /photos/1376371-loss
# https://knowyourmeme.com/memes/loss/photos/1376371-loss
# Retrieving Image 001_376_371_b10.jpg
# Retrieving img at href /photos/1376272-loss
# https://knowyourmeme.com/memes/loss/photos/1376272-loss
# Retrieving Image 001_376_272_683.jpg
# Retrieving img at href /photos/1376240-loss
# https://knowyourmeme.com/memes/loss/photos/1376240-loss
# Retrieving Image 001_376_240_2e7.jpg
# Retrieving img at href /photos/1375933-loss
# https://knowyourmeme.com/memes/loss/photos/1375933-loss
# Retrieving Image 001_375_933_22e.png
# Retrieving img at href /photos/1375928-loss
# https://knowyourmeme.com/memes/loss/photos/1375928-loss
# Retrieving Image 001_375_928_742.jpeg
# Retrieving img at href /photos/1375569-loss
# https://knowyourmeme.com/memes/loss/photos/1375569-loss
# Retrieving Image 001_375_569_54c.jpeg
# Retrieving img at href /photos/1375460-loss
# https://knowyourmeme.com/memes/loss/photos/1375460-loss
# Retrieving Image 001_375_460_c18.jpg
# Retrieving img at href /photos/1374897-loss
# https://knowyourmeme.com/memes/loss/photos/1374897-loss
# Retrieving Image 001_374_897_2aa.jpg_large
# Retrieving img at href /photos/1374895-loss
# https://knowyourmeme.com/memes/loss/photos/1374895-loss
# Retrieving Image 001_374_895_b11.jpeg
# Retrieving img at href /photos/1374213-loss
# https://knowyourmeme.com/memes/loss/photos/1374213-loss
# Retrieving Image 001_374_213_0d4.png
# Retrieving img at href /photos/1374179-loss
# https://knowyourmeme.com/memes/loss/photos/1374179-loss
# Retrieving Image 001_374_179_f81.png
# Retrieving img at href /photos/1374118-loss
# https://knowyourmeme.com/memes/loss/photos/1374118-loss
# Retrieving Image 001_374_118_ac9.jpg
# Retrieving img at href /photos/1374057-loss
# https://knowyourmeme.com/memes/loss/photos/1374057-loss
# Retrieving Image 001_374_057_41f.jpg
# Retrieving img at href /photos/1374018-loss
# https://knowyourmeme.com/memes/loss/photos/1374018-loss
# Retrieving Image 001_374_018_684.jpg
# Retrieving img at href /photos/1373288-loss
# https://knowyourmeme.com/memes/loss/photos/1373288-loss
# Retrieving Image 001_373_288_760.png
# Retrieving img at href /photos/1373272-loss
# https://knowyourmeme.com/memes/loss/photos/1373272-loss
# Retrieving Image 001_373_272_bd2.png
# Retrieving img at href /photos/1373190-loss
# https://knowyourmeme.com/memes/loss/photos/1373190-loss
# Retrieving Image 001_373_190_184.jpg
# Retrieving img at href /photos/1373175-loss
# https://knowyourmeme.com/memes/loss/photos/1373175-loss
# Retrieving Image 001_373_175_bde.png
# Retrieving img at href /photos/1372993-loss
# https://knowyourmeme.com/memes/loss/photos/1372993-loss
# Retrieving Image 001_372_993_356.png
# Retrieving img at href /photos/1372793-loss
# https://knowyourmeme.com/memes/loss/photos/1372793-loss
# Retrieving Image 001_372_793_d26.png
# Retrieving img at href /photos/1372619-loss
# https://knowyourmeme.com/memes/loss/photos/1372619-loss
# Retrieving Image 001_372_619_7b9.png
# Retrieving img at href /photos/1372441-loss
# https://knowyourmeme.com/memes/loss/photos/1372441-loss
# Retrieving Image 001_372_441_fdb.jpg
# Retrieving img at href /photos/1372415-loss
# https://knowyourmeme.com/memes/loss/photos/1372415-loss
# Retrieving Image 001_372_415_a53.png
# Retrieving img at href /photos/1372260-loss
# https://knowyourmeme.com/memes/loss/photos/1372260-loss
# Retrieving Image 001_372_260_193.jpg_large
# Retrieving img at href /photos/1372201-loss
# https://knowyourmeme.com/memes/loss/photos/1372201-loss
# Retrieving Image 001_372_201_b99.png
# Retrieving img at href /photos/1372197-loss
# https://knowyourmeme.com/memes/loss/photos/1372197-loss
# Retrieving Image 001_372_197_0b4.png
# Retrieving img at href /photos/1372029-loss
# https://knowyourmeme.com/memes/loss/photos/1372029-loss
# Retrieving Image 001_372_029_e22.jpg
# Retrieving img at href /photos/1371881-loss
# https://knowyourmeme.com/memes/loss/photos/1371881-loss
# Retrieving Image 001_371_881_39d.jpg
# Retrieving img at href /photos/1371861-loss
# https://knowyourmeme.com/memes/loss/photos/1371861-loss
# Retrieving Image 001_371_861_8d2.jpg
# Retrieving img at href /photos/1371620-loss
# https://knowyourmeme.com/memes/loss/photos/1371620-loss
# Retrieving Image 001_371_620_e18.jpg
# Retrieving img at href /photos/1371574-loss
# https://knowyourmeme.com/memes/loss/photos/1371574-loss
# Retrieving Image 001_371_574_50b.jpg
# Retrieving img at href /photos/1371501-loss
# https://knowyourmeme.com/memes/loss/photos/1371501-loss
# Retrieving Image 001_371_501_718.png
# Retrieving img at href /photos/1371484-loss
# https://knowyourmeme.com/memes/loss/photos/1371484-loss
# Retrieving Image 001_371_484_1fb.png
# Retrieving img at href /photos/1371470-loss
# https://knowyourmeme.com/memes/loss/photos/1371470-loss
# Retrieving Image 001_371_470_53d.jpg
# Retrieving img at href /photos/1371466-loss
# https://knowyourmeme.com/memes/loss/photos/1371466-loss
# Retrieving Image 001_371_466_abe.png
# Retrieving img at href /photos/1371410-loss
# https://knowyourmeme.com/memes/loss/photos/1371410-loss
# Retrieving Image 001_371_410_4fc.png
# Retrieving img at href /photos/1371390-loss
# https://knowyourmeme.com/memes/loss/photos/1371390-loss
# Retrieving Image 001_371_390_e50.png
# Retrieving img at href /photos/1371140-loss
# https://knowyourmeme.com/memes/loss/photos/1371140-loss
# ...
# Retrieving Image 001_205_071_24c.jpg
# Retrieving img at href /photos/1204714-loss
# https://knowyourmeme.com/memes/loss/photos/1204714-loss
# Retrieving Image 001_204_714_f35.png
# Retrieving img at href /photos/1204511-loss
# https://knowyourmeme.com/memes/loss/photos/1204511-loss
# Retrieving Image 001_204_511_863.jpg
# Retrieving img at href /photos/1202763-loss
# https://knowyourmeme.com/memes/loss/photos/1202763-loss
# Retrieving Image 001_202_763_24c.png
# Retrieving img at href /photos/1201895-loss
# https://knowyourmeme.com/memes/loss/photos/1201895-loss
# Retrieving Image 001_201_895_2cc.jpg
# Retrieving img at href /photos/1198704-loss
# https://knowyourmeme.com/memes/loss/photos/1198704-loss
# Retrieving Image 001_198_704_562.png
# Retrieving img at href /photos/1198361-loss
# https://knowyourmeme.com/memes/loss/photos/1198361-loss
# Retrieving Image 001_198_361_f4c.jpg
# Retrieving img at href /photos/1198107-loss
# https://knowyourmeme.com/memes/loss/photos/1198107-loss
# Retrieving Image 001_198_107_05d.png
# Retrieving img at href /photos/1197639-loss
# https://knowyourmeme.com/memes/loss/photos/1197639-loss
# Retrieving Image 001_197_639_945.png
# Retrieving img at href /photos/1197052-loss
# https://knowyourmeme.com/memes/loss/photos/1197052-loss
# Retrieving Image 001_197_052_7ae.jpg
# Retrieving img at href /photos/1196986-loss
# https://knowyourmeme.com/memes/loss/photos/1196986-loss
# Retrieving Image 001_196_986_643.png
# Retrieving img at href /photos/1196609-loss
# https://knowyourmeme.com/memes/loss/photos/1196609-loss
# Retrieving Image 001_196_609_0a1.gif
# Retrieving img at href /photos/1196608-loss
# https://knowyourmeme.com/memes/loss/photos/1196608-loss
# Retrieving Image 001_196_608_2aa.png
# Retrieving img at href /photos/1196422-loss
# https://knowyourmeme.com/memes/loss/photos/1196422-loss
# Retrieving Image 001_196_422_008.png
# Retrieving img at href /photos/1196155-loss
# https://knowyourmeme.com/memes/loss/photos/1196155-loss
# Retrieving Image 001_196_155_f87.jpg
# Retrieving img at href /photos/1196151-loss
# https://knowyourmeme.com/memes/loss/photos/1196151-loss
# Retrieving Image 001_196_151_472.jpg
# Retrieving img at href /photos/1195644-loss
# https://knowyourmeme.com/memes/loss/photos/1195644-loss
# Retrieving Image 001_195_644_fe2.jpg
# Retrieving img at href /photos/1195196-loss
# https://knowyourmeme.com/memes/loss/photos/1195196-loss
# Retrieving Image 001_195_196_64e.png
# Retrieving img at href /photos/1193793-loss
# https://knowyourmeme.com/memes/loss/photos/1193793-loss
# Retrieving Image 001_193_793_adf.png
# Retrieving img at href /photos/1193615-loss
# https://knowyourmeme.com/memes/loss/photos/1193615-loss
# Retrieving Image 001_193_615_100.jpg
# Retrieving img at href /photos/1193610-loss
# https://knowyourmeme.com/memes/loss/photos/1193610-loss
# Retrieving Image 001_193_610_6af.jpg
# Retrieving img at href /photos/1193608-loss
# https://knowyourmeme.com/memes/loss/photos/1193608-loss
# Retrieving Image 001_193_608_1c0.jpg
# Retrieving img at href /photos/1193607-loss
# https://knowyourmeme.com/memes/loss/photos/1193607-loss
# Retrieving Image 001_193_607_731.png
# Retrieving img at href /photos/1193605-loss
# https://knowyourmeme.com/memes/loss/photos/1193605-loss
# Retrieving Image 001_193_605_658.png
# Retrieving img at href /photos/1193460-loss
# https://knowyourmeme.com/memes/loss/photos/1193460-loss
# Retrieving Image 001_193_460_4a0.png
# Retrieving img at href /photos/1193076-loss
# https://knowyourmeme.com/memes/loss/photos/1193076-loss
# Retrieving Image 001_193_076_2d5.png
# Retrieving img at href /photos/1192933-loss
# https://knowyourmeme.com/memes/loss/photos/1192933-loss
# Retrieving Image 001_192_933_7ec.png
# Retrieving img at href /photos/1192663-loss
# https://knowyourmeme.com/memes/loss/photos/1192663-loss
# Retrieving Image 001_192_663_26e.png
# Retrieving img at href /photos/1192273-loss
# https://knowyourmeme.com/memes/loss/photos/1192273-loss
# Retrieving Image 001_192_273_119.png
# Retrieving img at href /photos/1191942-loss
# https://knowyourmeme.com/memes/loss/photos/1191942-loss
# Retrieving Image 001_191_942_154.png
# Retrieving img at href /photos/1190671-loss
# https://knowyourmeme.com/memes/loss/photos/1190671-loss
# Retrieving Image 001_190_671_f2a.png
# Retrieving img at href /photos/1189032-loss
# https://knowyourmeme.com/memes/loss/photos/1189032-loss
# Retrieving Image 001_189_032_8a5.png
# Retrieving img at href /photos/1188758-loss
# https://knowyourmeme.com/memes/loss/photos/1188758-loss
# Retrieving Image 001_188_758_997.png
# Retrieving img at href /photos/1188312-loss
# https://knowyourmeme.com/memes/loss/photos/1188312-loss
# Retrieving Image 001_188_312_cb6.png
# Retrieving img at href /photos/1188138-loss
# https://knowyourmeme.com/memes/loss/photos/1188138-loss
# Retrieving Image 001_188_138_9f5.png
# Retrieving img at href /photos/1187554-loss
# https://knowyourmeme.com/memes/loss/photos/1187554-loss
# Retrieving Image 001_187_554_3ae.jpg
# Retrieving img at href /photos/1187439-loss
# https://knowyourmeme.com/memes/loss/photos/1187439-loss
# Retrieving Image 001_187_439_7aa.jpg
# Retrieving img at href /photos/1186737-loss
# https://knowyourmeme.com/memes/loss/photos/1186737-loss
# Retrieving Image 001_186_737_477.png
# Retrieving img at href /photos/1186249-loss
# https://knowyourmeme.com/memes/loss/photos/1186249-loss
# Retrieving Image 001_186_249_4e0.jpg
# Retrieving img at href /photos/1186247-loss
# https://knowyourmeme.com/memes/loss/photos/1186247-loss
# Retrieving Image 001_186_247_88e.png
# Retrieving img at href /photos/1184598-loss
# https://knowyourmeme.com/memes/loss/photos/1184598-loss
# Retrieving Image 001_184_598_3cf.jpg_large
# Retrieving img at href /photos/1184585-loss
# https://knowyourmeme.com/memes/loss/photos/1184585-loss
# Retrieving Image 001_184_585_169.png
# Retrieving img at href /photos/1184327-loss
# https://knowyourmeme.com/memes/loss/photos/1184327-loss
# Retrieving Image 001_184_327_390.png
# Retrieving img at href /photos/1184326-loss
# https://knowyourmeme.com/memes/loss/photos/1184326-loss
# Retrieving Image 001_184_326_674.jpg
# Retrieving img at href /photos/1183321-loss
# https://knowyourmeme.com/memes/loss/photos/1183321-loss
# Retrieving Image 001_183_321_428.png
# Retrieving img at href /photos/1183213-loss
# https://knowyourmeme.com/memes/loss/photos/1183213-loss
# Retrieving Image 001_183_213_cf5.jpg
# Retrieving img at href /photos/1183072-loss
# https://knowyourmeme.com/memes/loss/photos/1183072-loss
# Retrieving Image 001_183_072_88f.png
# Retrieving img at href /photos/1182560-loss
# https://knowyourmeme.com/memes/loss/photos/1182560-loss
# Retrieving Image 001_182_560_71e.png
# Retrieving img at href /photos/1182085-loss
# https://knowyourmeme.com/memes/loss/photos/1182085-loss
# Retrieving Image 001_182_085_d96.jpg
# Retrieving img at href /photos/1181859-loss
# https://knowyourmeme.com/memes/loss/photos/1181859-loss
# Retrieving Image 001_181_859_8a4.jpg
# Retrieving img at href /photos/1181800-loss
# https://knowyourmeme.com/memes/loss/photos/1181800-loss
# Retrieving Image 001_181_800_980.jpg
# Retrieving img at href /photos/1181454-loss
# https://knowyourmeme.com/memes/loss/photos/1181454-loss
# Retrieving Image 001_181_454_3ca.png
# Retrieving img at href /photos/1181433-loss
# https://knowyourmeme.com/memes/loss/photos/1181433-loss
# Retrieving Image 001_181_433_704.png
# Retrieving img at href /photos/1180223-loss
# https://knowyourmeme.com/memes/loss/photos/1180223-loss
# Retrieving Image 001_180_223_084.png
# Retrieving img at href /photos/1180194-loss
# https://knowyourmeme.com/memes/loss/photos/1180194-loss
# Retrieving Image 001_180_194_e7e.png
# Retrieving img at href /photos/1177347-loss
# https://knowyourmeme.com/memes/loss/photos/1177347-loss
# Retrieving Image 001_177_347_658.png
# Retrieving img at href /photos/1177322-loss
# https://knowyourmeme.com/memes/loss/photos/1177322-loss
# Retrieving Image 001_177_322_729.jpg
# Retrieving img at href /photos/1177087-loss
# https://knowyourmeme.com/memes/loss/photos/1177087-loss
# Retrieving Image 001_177_087_c3e.png
# Retrieving img at href /photos/1176422-loss
# https://knowyourmeme.com/memes/loss/photos/1176422-loss
# Retrieving Image 001_176_422_0b3.png
# Retrieving img at href /photos/1175852-loss
# https://knowyourmeme.com/memes/loss/photos/1175852-loss
# Retrieving Image 001_175_852_902.png
# Retrieving img at href /photos/1175424-loss
# https://knowyourmeme.com/memes/loss/photos/1175424-loss
# Retrieving Image 001_175_424_178.png
# Retrieving img at href /photos/1174886-loss
# https://knowyourmeme.com/memes/loss/photos/1174886-loss
# Retrieving Image 001_174_886_a0d.png
# Retrieving img at href /photos/1172421-loss
# https://knowyourmeme.com/memes/loss/photos/1172421-loss
# Retrieving Image 001_172_421_2e6.png
# Retrieving img at href /photos/1171931-loss
# https://knowyourmeme.com/memes/loss/photos/1171931-loss
# Retrieving Image 001_171_931_7dc.jpg
# Retrieving img at href /photos/1171123-loss
# https://knowyourmeme.com/memes/loss/photos/1171123-loss
# Retrieving Image 001_171_123_798.png
# Retrieving img at href /photos/1170223-loss
# https://knowyourmeme.com/memes/loss/photos/1170223-loss
# Retrieving Image 001_170_223_da8.png
# Retrieving img at href /photos/1168663-loss
# https://knowyourmeme.com/memes/loss/photos/1168663-loss
# Retrieving Image 001_168_663_a94.png
# Retrieving img at href /photos/1168387-loss
# https://knowyourmeme.com/memes/loss/photos/1168387-loss
# Retrieving Image 001_168_387_331.png
# Retrieving img at href /photos/1168384-loss
# https://knowyourmeme.com/memes/loss/photos/1168384-loss
# Retrieving Image 001_168_384_b8f.png
# Retrieving img at href /photos/1168192-loss
# https://knowyourmeme.com/memes/loss/photos/1168192-loss
# Retrieving Image 001_168_192_97e.png
# Retrieving img at href /photos/1167945-loss
# https://knowyourmeme.com/memes/loss/photos/1167945-loss
# Retrieving Image 001_167_945_70a.jpg
# Retrieving img at href /photos/1167835-loss
# https://knowyourmeme.com/memes/loss/photos/1167835-loss
# Retrieving Image 001_167_835_33c.jpg
# Retrieving img at href /photos/1165692-loss
# https://knowyourmeme.com/memes/loss/photos/1165692-loss
# Retrieving Image 001_165_692_3a2.jpg
# Retrieving img at href /photos/1165585-loss
# https://knowyourmeme.com/memes/loss/photos/1165585-loss
# Retrieving Image 001_165_585_a3d.jpg
# Retrieving img at href /photos/1165408-loss
# https://knowyourmeme.com/memes/loss/photos/1165408-loss
# Retrieving Image 001_165_408_3b1.png
# Retrieving img at href /photos/1165295-loss
# https://knowyourmeme.com/memes/loss/photos/1165295-loss
# Retrieving Image 001_165_295_b42.png
# Retrieving img at href /photos/1165050-loss
# https://knowyourmeme.com/memes/loss/photos/1165050-loss
# Retrieving Image 001_165_050_08c.png
# Retrieving img at href /photos/1162929-loss
# https://knowyourmeme.com/memes/loss/photos/1162929-loss
# Retrieving Image 001_162_929_80d.png
# Retrieving img at href /photos/1162839-loss
# https://knowyourmeme.com/memes/loss/photos/1162839-loss
# Retrieving Image 001_162_839_22f.jpg_large
# Retrieving img at href /photos/1162501-loss
# https://knowyourmeme.com/memes/loss/photos/1162501-loss
# Retrieving Image 001_162_501_182.jpg
# Retrieving img at href /photos/1162445-loss
# https://knowyourmeme.com/memes/loss/photos/1162445-loss
# Retrieving Image 001_162_445_e8c.png
# Retrieving img at href /photos/1161523-loss
# https://knowyourmeme.com/memes/loss/photos/1161523-loss
# Retrieving Image 001_161_523_907.png
# Retrieving img at href /photos/1161346-loss
# https://knowyourmeme.com/memes/loss/photos/1161346-loss
# Retrieving Image 001_161_346_276.jpg
# Retrieving img at href /photos/1160782-loss
# https://knowyourmeme.com/memes/loss/photos/1160782-loss
# Retrieving Image 001_160_782_66d.jpg
# Retrieving img at href /photos/1160160-loss
# https://knowyourmeme.com/memes/loss/photos/1160160-loss
# Retrieving Image 001_160_160_4d4.jpg
# Retrieving img at href /photos/1159386-loss
# https://knowyourmeme.com/memes/loss/photos/1159386-loss
# Retrieving Image 001_159_386_2c6.png
# Retrieving img at href /photos/1159211-loss
# https://knowyourmeme.com/memes/loss/photos/1159211-loss
# Retrieving Image 001_159_211_288.png
# Retrieving img at href /photos/1158996-loss
# https://knowyourmeme.com/memes/loss/photos/1158996-loss
# Retrieving Image 001_158_996_201.png
# Retrieving img at href /photos/1157683-loss
# https://knowyourmeme.com/memes/loss/photos/1157683-loss
# Retrieving Image 001_157_683_19f.png
# Retrieving img at href /photos/1156530-loss
# https://knowyourmeme.com/memes/loss/photos/1156530-loss
# Retrieving Image 001_156_530_cb6.jpg
# Retrieving img at href /photos/1156181-loss
# https://knowyourmeme.com/memes/loss/photos/1156181-loss
# Retrieving Image 001_156_181_68e.jpg
# Retrieving img at href /photos/1155520-loss
# https://knowyourmeme.com/memes/loss/photos/1155520-loss
# Retrieving Image 001_155_520_17a.png
# Retrieving img at href /photos/1155124-loss
# https://knowyourmeme.com/memes/loss/photos/1155124-loss
# Retrieving Image 001_155_124_d5c.png
# Retrieving img at href /photos/1154877-loss
# https://knowyourmeme.com/memes/loss/photos/1154877-loss
# Retrieving Image 001_154_877_a7a.jpg
# Retrieving img at href /photos/1154323-loss
# https://knowyourmeme.com/memes/loss/photos/1154323-loss
# Retrieving Image 001_154_323_77f.jpg
# Retrieving img at href /photos/1154152-loss
# https://knowyourmeme.com/memes/loss/photos/1154152-loss
# Retrieving Image 001_154_152_55f.jpg
# Retrieving img at href /photos/1153507-loss
# https://knowyourmeme.com/memes/loss/photos/1153507-loss
# Retrieving Image 001_153_507_6c1.jpg
# Retrieving img at href /photos/1153497-loss
# https://knowyourmeme.com/memes/loss/photos/1153497-loss
# Retrieving Image 001_153_497_a65.png
# Retrieving img at href /photos/1151974-loss
# https://knowyourmeme.com/memes/loss/photos/1151974-loss
# Retrieving Image 001_151_974_a39.jpg
# Retrieving img at href /photos/1151466-loss
# https://knowyourmeme.com/memes/loss/photos/1151466-loss
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-3-db84c4155632> in kym_gallery_pull(name)
#      88             reqIMG = Request(str(imgURL), headers={'User-Agent': 'Mozilla/5.0'})
# ---> 89             imgpage = urlopen(reqIMG).read()
#      90             soup = bs(imgpage, 'html.parser') #, from_encoding="iso-8859-1"
#
# ~/anaconda3/envs/Research_env/lib/python3.7/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#
# ~/anaconda3/envs/Research_env/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#
# ~/anaconda3/envs/Research_env/lib/python3.7/urllib/request.py in http_response(self, request, response)
#     640             response = self.parent.error(
# --> 641                 'http', request, response, code, msg, hdrs)
#     642
#
# ~/anaconda3/envs/Research_env/lib/python3.7/urllib/request.py in error(self, proto, *args)
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#
# ~/anaconda3/envs/Research_env/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#
# ~/anaconda3/envs/Research_env/lib/python3.7/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#
# HTTPError: HTTP Error 403: Forbidden
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-2d0e7f02ab1b> in <module>
# ----> 1 kym_gallery_pull('loss')
#
# <ipython-input-3-db84c4155632> in kym_gallery_pull(name)
#     179           , index=False)
#     180     except:
# --> 181         traceback.print_exc(file=out)
#     182     out.write('Metadata file completed.\n')
#     183     #print('Metadata file completed.')
#
# NameError: name 'traceback' is not defined

# %%
###############################################################################################################
# Meme Library Scrape: Version 1 ##############################################################################
###############################################################################################################
# TO DO:
# 1. Figure out how to get proxy ips that aren't 1xx or 4xx errors
# 2. Call this function within an exception in the above function
# 3. Create outfile statements
# 4. Give better comments
#def meme_entry_db():
n = 1

def get_proxies():
    url = 'https://free-proxy-list.net/'
    response = Request(url, headers={'User-Agent': 'Mozilla/5.0'})
    proxy_pg = urlopen(response).read()
    proxy_root = etree.HTML(proxy_pg)
    result = etree.tostring(proxy_root, pretty_print=True, method="html")
    #bs(proxy_pg, 'html.parser', from_encoding="iso-8859-1")
    proxy_xpth = "//*[@id='list']/div/div[2]/div/table/tbody/tr/td[1]/text()"
    ips = proxy_root.xpath(proxy_xpth)
    return ips 

ips = get_proxies()
#print(ips)
#print(f'Retrieving meme hrefs from page {n} of All Memes on KYM...')

# %%
cols = ['meme_entry_ID','meme_names','meme_sufs', 'meme_gallery_ID', 'meme_gallery','meme_labels']
meme_entry_df = pd.DataFrame(columns=cols)
url_pg = 'https://knowyourmeme.com/memes/all'
req_pg = Request(url_pg, headers={'User-Agent': 'Mozilla/5.0'})
ip = random.choice(tuple(ips))
print(ip)
req_pg.set_proxy(ip, 'http')
print(req_pg)
webpage_pg = urlopen(req_pg).read()
root_pg = etree.HTML(webpage_pg)
while root_pg.xpath("//section[@id='entries']//table[@class='entry_list']//td[contains(@class, 'entry_')]") != 0:
    # Connecting to Meme Entry's Page N
    row = []
    print(f'Retrieving meme hrefs from page {n} of All Memes on KYM...')
    req_pg = Request(url_pg, headers={'User-Agent': 'Mozilla/5.0'})
    req_pg.set_proxy(random.choice(tuple(ips)), 'http')

    webpage_pg = urlopen(req_pg).read()
    root_pg = etree.HTML(webpage_pg)
    result = etree.tostring(root_pg, pretty_print=True, method="html")
    xpth = "//section[@id='entries']//table[@class='entry_list']//td[contains(@class, 'entry_')]/a[@href]//@href"
    meme_sufs = root_pg.xpath(xpth)
    xpth2 = "//section[@id='entries']//table[@class='entry_list']//td[contains(@class, 'entry_')]/a/img[@title]/@title"
    meme_names = root_pg.xpath(xpth2)
    if len(meme_sufs) == 0:
        print('There are no more memes to scrape./nENDING SCRIPT')
        break

    xpth2 = "//section[@id='entries']//table[@class='entry_list']//td[contains(@class, 'entry_')]/@class"
    entry = root_pg.xpath(xpth2)
    meme_labels = []
    for id in entry:
        labs = f"//section[@id='entries']//table[@class='entry_list']//td[@class='{id}']//span/text()"
        lab = root_pg.xpath(labs)
        meme_labels.append(lab)
    meme_urls = []
    meme_IDurls = []
    for i in range(0,len(entry)):
        meme_url = 'https://knowyourmeme.com' + meme_sufs[i] + '/photos/'
        entry_id = [re.sub('entry_', '', i) for i in entry]
        #print(entry_id)
        meme_entryID_url = 'https://knowyourmeme.com/memes/' + entry_id[i] + '/photos/'
        meme_urls.append(meme_url)
        meme_IDurls.append(meme_entryID_url)

    # Building row to append to meme_entry_df
    for i in range(0,len(entry)):
        #Append row in this order
        row = ([entry[i],meme_names[i], meme_sufs[i], meme_IDurls[i],  meme_urls[i], meme_labels[i]])
        df = pd.DataFrame([row], columns=cols)
        #print(df2)
        meme_entry_df = meme_entry_df.append(df, ignore_index=True)

    # Sleep statement to avoid 403 from KYM    
    sleep(randint(1,60))

    n+=1
    url = 'https://knowyourmeme.com/memes/all'
    url_pg = f'{url}/page/{n}'
    url_len = len(root_pg.xpath(
        "//section[@id='entries']//table[@class='entry_list']//td[contains(@class, 'entry_')]"))

# From the list of meme_names create the url to each meme submission.

metadata_df.to_csv(
    f'./GCV_FuncTestData/{name}_KYMEntry_{dateMDY}.csv'
    ,index=False)

print(f'Retreived all meme galleries.\n')

#    return meme_entry_df
# Out:
# 202.75.97.82
# <urllib.request.Request object at 0x7f5b4987dd90>
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# ~/anaconda3/envs/Research_env/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1349                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1350                           encode_chunked=req.has_header('Transfer-encoding'))
#    1351             except OSError as err: # timeout error
#
# ~/anaconda3/envs/Research_env/lib/python3.7/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1276         """Send a complete request to the server."""
# -> 1277         self._send_request(method, url, body, headers, encode_chunked)
#    1278
#
# ~/anaconda3/envs/Research_env/lib/python3.7/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1322             body = _encode(body, 'body')
# -> 1323         self.endheaders(body, encode_chunked=encode_chunked)
#    1324
#
# ~/anaconda3/envs/Research_env/lib/python3.7/http/client.py in endheaders(self, message_body, encode_chunked)
#    1271             raise CannotSendHeader()
# -> 1272         self._send_output(message_body, encode_chunked=encode_chunked)
#    1273
#
# ~/anaconda3/envs/Research_env/lib/python3.7/http/client.py in _send_output(self, message_body, encode_chunked)
#    1031         del self._buffer[:]
# -> 1032         self.send(msg)
#    1033
#
# ~/anaconda3/envs/Research_env/lib/python3.7/http/client.py in send(self, data)
#     971             if self.auto_open:
# --> 972                 self.connect()
#     973             else:
#
# ~/anaconda3/envs/Research_env/lib/python3.7/http/client.py in connect(self)
#    1438
# -> 1439             super().connect()
#    1440
#
# ~/anaconda3/envs/Research_env/lib/python3.7/http/client.py in connect(self)
#     943         self.sock = self._create_connection(
# --> 944             (self.host,self.port), self.timeout, self.source_address)
#     945         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#
# ~/anaconda3/envs/Research_env/lib/python3.7/socket.py in create_connection(address, timeout, source_address)
#     727         try:
# --> 728             raise err
#     729         finally:
#
# ~/anaconda3/envs/Research_env/lib/python3.7/socket.py in create_connection(address, timeout, source_address)
#     715                 sock.bind(source_address)
# --> 716             sock.connect(sa)
#     717             # Break explicitly a reference cycle
#
# ConnectionRefusedError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# <ipython-input-37-f6ccb77b678a> in <module>
#       7 req_pg.set_proxy(ip, 'http')
#       8 print(req_pg)
# ----> 9 webpage_pg = urlopen(req_pg).read()
#      10 root_pg = etree.HTML(webpage_pg)
#      11 while root_pg.xpath("//section[@id='entries']//table[@class='entry_list']//td[contains(@class, 'entry_')]") != 0:
#
# ~/anaconda3/envs/Research_env/lib/python3.7/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~/anaconda3/envs/Research_env/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     523             req = meth(req)
#     524
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# ~/anaconda3/envs/Research_env/lib/python3.7/urllib/request.py in _open(self, req, data)
#     541         protocol = req.type
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#     545             return result
#
# ~/anaconda3/envs/Research_env/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# ~/anaconda3/envs/Research_env/lib/python3.7/urllib/request.py in https_open(self, req)
#    1391         def https_open(self, req):
#    1392             return self.do_open(http.client.HTTPSConnection, req,
# -> 1393                 context=self._context, check_hostname=self._check_hostname)
#    1394
#    1395         https_request = AbstractHTTPHandler.do_request_
#
# ~/anaconda3/envs/Research_env/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1350                           encode_chunked=req.has_header('Transfer-encoding'))
#    1351             except OSError as err: # timeout error
# -> 1352                 raise URLError(err)
#    1353             r = h.getresponse()
#    1354         except:
#
# URLError: <urlopen error [Errno 111] Connection refused>

# %%
# Metadata Test Script
url = 'https://knowyourmeme.com/memes/all/'
req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})
webpage = urlopen(req).read()
soup = bs(webpage, 'html.parser', from_encoding="iso-8859-1")

# Load webpage into ELement Tree format for XPath search for first page image count:
root = etree.HTML(webpage)
result = etree.tostring(root, pretty_print=True, method="html")

n = 1 #begin iterable for each KYM Gallery Page URL
url_suffixes = [] #being the list of url directorys after the url prefix for each image

# While loop runs so long as the photo_gallery is not empty
url_len = len(root.xpath("//section[@id='entries']//table[@class='entry_list']//td[contains(@class, 'entry_')]//a[@href]//@href"))

meme_sufs = []
meme_names = []

url_pg = url
# While loop runs so long as the photo_gallery is not empty
while  url_len != 0:
    print(f'Retrieving meme hrefs from page {n} of All Memes on KYM...')
    req_pg = Request(url_pg, headers={'User-Agent': 'Mozilla/5.0'})
    webpg = urlopen(req_pg).read()
    root_pg = etree.HTML(webpg)
    result = etree.tostring(root_pg, pretty_print=True, method="html")
    xpth = "//section[@id='entries']//table[@class='entry_list']//td[contains(@class, 'entry_')]/a[@href]//@href"
    meme_sufs = meme_sufs + root_pg.xpath(xpth)
    xpth2 = "//section[@id='entries']//table[@class='entry_list']//td[contains(@class, 'entry_')]/a/img[@title]/@title"
    meme_names = meme_names + root_pg.xpath(xpth2)

    #print(meme_sufs)
    # Iterate to the next n to get the next KYM Gallery Page in 'memeURL' above
    n+=1
    url_pg = f'{url}/page/{n}'
    url_len = len(root_pg.xpath(
        "//section[@id='entries']//table[@class='entry_list']//td[contains(@class, 'entry_')]"))

print(f'Retreived all meme galleries.\n')
# Out:
# Retrieving meme hrefs from page 1 of All Memes on KYM...
# Retrieving meme hrefs from page 2 of All Memes on KYM...
# Retrieving meme hrefs from page 3 of All Memes on KYM...
# Retrieving meme hrefs from page 4 of All Memes on KYM...
# Retrieving meme hrefs from page 5 of All Memes on KYM...
# Retrieving meme hrefs from page 6 of All Memes on KYM...
# Retrieving meme hrefs from page 7 of All Memes on KYM...
# Retrieving meme hrefs from page 8 of All Memes on KYM...
# Retrieving meme hrefs from page 9 of All Memes on KYM...
# Retrieving meme hrefs from page 10 of All Memes on KYM...
# Retrieving meme hrefs from page 11 of All Memes on KYM...
# Retrieving meme hrefs from page 12 of All Memes on KYM...
# Retrieving meme hrefs from page 13 of All Memes on KYM...
# Retrieving meme hrefs from page 14 of All Memes on KYM...
# Retrieving meme hrefs from page 15 of All Memes on KYM...
# Retrieving meme hrefs from page 16 of All Memes on KYM...
# Retrieving meme hrefs from page 17 of All Memes on KYM...
# Retrieving meme hrefs from page 18 of All Memes on KYM...
# Retrieving meme hrefs from page 19 of All Memes on KYM...
# Retrieving meme hrefs from page 20 of All Memes on KYM...
# Retrieving meme hrefs from page 21 of All Memes on KYM...
# Retrieving meme hrefs from page 22 of All Memes on KYM...
# Retrieving meme hrefs from page 23 of All Memes on KYM...
# Retrieving meme hrefs from page 24 of All Memes on KYM...
# Retrieving meme hrefs from page 25 of All Memes on KYM...
# Retrieving meme hrefs from page 26 of All Memes on KYM...
# Retrieving meme hrefs from page 27 of All Memes on KYM...
# Retrieving meme hrefs from page 28 of All Memes on KYM...
# Retrieving meme hrefs from page 29 of All Memes on KYM...
# Retrieving meme hrefs from page 30 of All Memes on KYM...
# Retrieving meme hrefs from page 31 of All Memes on KYM...
# Retrieving meme hrefs from page 32 of All Memes on KYM...
# Retrieving meme hrefs from page 33 of All Memes on KYM...
# Retrieving meme hrefs from page 34 of All Memes on KYM...
# Retrieving meme hrefs from page 35 of All Memes on KYM...
# Retrieving meme hrefs from page 36 of All Memes on KYM...
# Retrieving meme hrefs from page 37 of All Memes on KYM...
# Retrieving meme hrefs from page 38 of All Memes on KYM...
# Retrieving meme hrefs from page 39 of All Memes on KYM...
# Retrieving meme hrefs from page 40 of All Memes on KYM...
# Retrieving meme hrefs from page 41 of All Memes on KYM...
# Retrieving meme hrefs from page 42 of All Memes on KYM...
# Retrieving meme hrefs from page 43 of All Memes on KYM...
# Retrieving meme hrefs from page 44 of All Memes on KYM...
# Retrieving meme hrefs from page 45 of All Memes on KYM...
# Retrieving meme hrefs from page 46 of All Memes on KYM...
# Retrieving meme hrefs from page 47 of All Memes on KYM...
# Retrieving meme hrefs from page 48 of All Memes on KYM...
# Retrieving meme hrefs from page 49 of All Memes on KYM...
# Retrieving meme hrefs from page 50 of All Memes on KYM...
# Retrieving meme hrefs from page 51 of All Memes on KYM...
# Retrieving meme hrefs from page 52 of All Memes on KYM...
# Retrieving meme hrefs from page 53 of All Memes on KYM...
# Retrieving meme hrefs from page 54 of All Memes on KYM...
# Retrieving meme hrefs from page 55 of All Memes on KYM...
# Retrieving meme hrefs from page 56 of All Memes on KYM...
# Retrieving meme hrefs from page 57 of All Memes on KYM...
# Retrieving meme hrefs from page 58 of All Memes on KYM...
# Retrieving meme hrefs from page 59 of All Memes on KYM...
# Retrieving meme hrefs from page 60 of All Memes on KYM...
# Retrieving meme hrefs from page 61 of All Memes on KYM...
# Retrieving meme hrefs from page 62 of All Memes on KYM...
# Retrieving meme hrefs from page 63 of All Memes on KYM...
# Retrieving meme hrefs from page 64 of All Memes on KYM...
# Retrieving meme hrefs from page 65 of All Memes on KYM...
# Retrieving meme hrefs from page 66 of All Memes on KYM...
# Retrieving meme hrefs from page 67 of All Memes on KYM...
# Retrieving meme hrefs from page 68 of All Memes on KYM...
# Retrieving meme hrefs from page 69 of All Memes on KYM...
# Retrieving meme hrefs from page 70 of All Memes on KYM...
# Retrieving meme hrefs from page 71 of All Memes on KYM...
# Retrieving meme hrefs from page 72 of All Memes on KYM...
# Retrieving meme hrefs from page 73 of All Memes on KYM...
# Retrieving meme hrefs from page 74 of All Memes on KYM...
# Retrieving meme hrefs from page 75 of All Memes on KYM...
# Retrieving meme hrefs from page 76 of All Memes on KYM...
# Retrieving meme hrefs from page 77 of All Memes on KYM...
# Retrieving meme hrefs from page 78 of All Memes on KYM...
# Retrieving meme hrefs from page 79 of All Memes on KYM...
# Retrieving meme hrefs from page 80 of All Memes on KYM...
# Retrieving meme hrefs from page 81 of All Memes on KYM...
# Retrieving meme hrefs from page 82 of All Memes on KYM...
# Retrieving meme hrefs from page 83 of All Memes on KYM...
# Retrieving meme hrefs from page 84 of All Memes on KYM...
# Retrieving meme hrefs from page 85 of All Memes on KYM...
# Retrieving meme hrefs from page 86 of All Memes on KYM...
# Retrieving meme hrefs from page 87 of All Memes on KYM...
# Retrieving meme hrefs from page 88 of All Memes on KYM...
# Retrieving meme hrefs from page 89 of All Memes on KYM...
# Retrieving meme hrefs from page 90 of All Memes on KYM...
# Retrieving meme hrefs from page 91 of All Memes on KYM...
# Retrieving meme hrefs from page 92 of All Memes on KYM...
# Retrieving meme hrefs from page 93 of All Memes on KYM...
# Retrieving meme hrefs from page 94 of All Memes on KYM...
# Retrieving meme hrefs from page 95 of All Memes on KYM...
# Retrieving meme hrefs from page 96 of All Memes on KYM...
# Retrieving meme hrefs from page 97 of All Memes on KYM...
# Retrieving meme hrefs from page 98 of All Memes on KYM...
# Retrieving meme hrefs from page 99 of All Memes on KYM...
# Retrieving meme hrefs from page 100 of All Memes on KYM...
# Retrieving meme hrefs from page 101 of All Memes on KYM...
# Retrieving meme hrefs from page 102 of All Memes on KYM...
# Retrieving meme hrefs from page 103 of All Memes on KYM...
# Retrieving meme hrefs from page 104 of All Memes on KYM...
# Retrieving meme hrefs from page 105 of All Memes on KYM...
# Retrieving meme hrefs from page 106 of All Memes on KYM...
# Retrieving meme hrefs from page 107 of All Memes on KYM...
# Retrieving meme hrefs from page 108 of All Memes on KYM...
# Retrieving meme hrefs from page 109 of All Memes on KYM...
# Retrieving meme hrefs from page 110 of All Memes on KYM...
# Retrieving meme hrefs from page 111 of All Memes on KYM...
# Retrieving meme hrefs from page 112 of All Memes on KYM...
# Retrieving meme hrefs from page 113 of All Memes on KYM...
# Retrieving meme hrefs from page 114 of All Memes on KYM...
# Retrieving meme hrefs from page 115 of All Memes on KYM...
# Retrieving meme hrefs from page 116 of All Memes on KYM...
# Retrieving meme hrefs from page 117 of All Memes on KYM...
# Retrieving meme hrefs from page 118 of All Memes on KYM...
# Retrieving meme hrefs from page 119 of All Memes on KYM...
# Retrieving meme hrefs from page 120 of All Memes on KYM...
# Retrieving meme hrefs from page 121 of All Memes on KYM...
# Retrieving meme hrefs from page 122 of All Memes on KYM...
# Retrieving meme hrefs from page 123 of All Memes on KYM...
# Retrieving meme hrefs from page 124 of All Memes on KYM...
# Retrieving meme hrefs from page 125 of All Memes on KYM...
# Retrieving meme hrefs from page 126 of All Memes on KYM...
# Retrieving meme hrefs from page 127 of All Memes on KYM...
# Retrieving meme hrefs from page 128 of All Memes on KYM...
# Retrieving meme hrefs from page 129 of All Memes on KYM...
# Retrieving meme hrefs from page 130 of All Memes on KYM...
# Retrieving meme hrefs from page 131 of All Memes on KYM...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-7450ded14a10> in <module>
#      23     print(f'Retrieving meme hrefs from page {n} of All Memes on KYM...')
#      24     req_pg = Request(url_pg, headers={'User-Agent': 'Mozilla/5.0'})
# ---> 25     webpg = urlopen(req_pg).read()
#      26     root_pg = etree.HTML(webpg)
#      27     result = etree.tostring(root_pg, pretty_print=True, method="html")
#
# ~/anaconda3/envs/Research_env/lib/python3.7/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~/anaconda3/envs/Research_env/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     523             req = meth(req)
#     524
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# ~/anaconda3/envs/Research_env/lib/python3.7/urllib/request.py in _open(self, req, data)
#     541         protocol = req.type
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#     545             return result
#
# ~/anaconda3/envs/Research_env/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# ~/anaconda3/envs/Research_env/lib/python3.7/urllib/request.py in https_open(self, req)
#    1391         def https_open(self, req):
#    1392             return self.do_open(http.client.HTTPSConnection, req,
# -> 1393                 context=self._context, check_hostname=self._check_hostname)
#    1394
#    1395         https_request = AbstractHTTPHandler.do_request_
#
# ~/anaconda3/envs/Research_env/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1348             try:
#    1349                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1350                           encode_chunked=req.has_header('Transfer-encoding'))
#    1351             except OSError as err: # timeout error
#    1352                 raise URLError(err)
#
# ~/anaconda3/envs/Research_env/lib/python3.7/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1275                 encode_chunked=False):
#    1276         """Send a complete request to the server."""
# -> 1277         self._send_request(method, url, body, headers, encode_chunked)
#    1278
#    1279     def _send_request(self, method, url, body, headers, encode_chunked):
#
# ~/anaconda3/envs/Research_env/lib/python3.7/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1321             # default charset of iso-8859-1.
#    1322             body = _encode(body, 'body')
# -> 1323         self.endheaders(body, encode_chunked=encode_chunked)
#    1324
#    1325     def getresponse(self):
#
# ~/anaconda3/envs/Research_env/lib/python3.7/http/client.py in endheaders(self, message_body, encode_chunked)
#    1270         else:
#    1271             raise CannotSendHeader()
# -> 1272         self._send_output(message_body, encode_chunked=encode_chunked)
#    1273
#    1274     def request(self, method, url, body=None, headers={}, *,
#
# ~/anaconda3/envs/Research_env/lib/python3.7/http/client.py in _send_output(self, message_body, encode_chunked)
#    1030         msg = b"\r\n".join(self._buffer)
#    1031         del self._buffer[:]
# -> 1032         self.send(msg)
#    1033
#    1034         if message_body is not None:
#
# ~/anaconda3/envs/Research_env/lib/python3.7/http/client.py in send(self, data)
#     970         if self.sock is None:
#     971             if self.auto_open:
# --> 972                 self.connect()
#     973             else:
#     974                 raise NotConnected()
#
# ~/anaconda3/envs/Research_env/lib/python3.7/http/client.py in connect(self)
#    1437             "Connect to a host on a given (SSL) port."
#    1438
# -> 1439             super().connect()
#    1440
#    1441             if self._tunnel_host:
#
# ~/anaconda3/envs/Research_env/lib/python3.7/http/client.py in connect(self)
#     942         """Connect to the host and port specified in __init__."""
#     943         self.sock = self._create_connection(
# --> 944             (self.host,self.port), self.timeout, self.source_address)
#     945         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#     946
#
# ~/anaconda3/envs/Research_env/lib/python3.7/socket.py in create_connection(address, timeout, source_address)
#     714             if source_address:
#     715                 sock.bind(source_address)
# --> 716             sock.connect(sa)
#     717             # Break explicitly a reference cycle
#     718             err = None
#
# KeyboardInterrupt:

# %%
#kym_md_test()

# %%
# Out:
# ['118.201.86.149', '89.20.48.118', '213.230.69.193', '103.156.216.170', '14.177.236.212', '191.103.219.225', '160.16.149.58', '209.141.55.228', '206.253.164.122', '68.183.59.38', '20.81.62.32', '41.76.155.26', '139.99.237.62', '51.195.201.93', '199.19.226.12', '58.26.138.170', '103.216.103.25', '217.11.184.30', '154.16.63.16', '43.228.180.60', '54.219.16.162', '206.253.164.198', '179.96.28.58', '176.9.75.42', '46.4.96.137', '206.253.164.28', '68.183.56.232', '81.163.52.25', '191.96.42.80', '194.224.192.226', '162.241.76.185', '187.60.163.234', '43.224.10.27', '34.125.131.164', '18.218.101.232', '206.253.164.120', '206.253.164.110', '206.253.164.101', '88.198.50.103', '005.252.161.48', '139.162.78.109', '187.111.160.8', '199.19.225.250', '121.78.139.75', '199.19.224.3', '121.78.139.77', '201.55.170.221', '3.25.85.198', '176.9.119.170', '103.206.254.170', '212.50.36.245', '46.28.109.236', '178.124.152.21', '80.17.254.230', '37.187.146.176', '58.234.116.197', '64.17.30.238', '34.133.138.17', '41.222.209.12', '185.51.10.19', '41.65.252.101', '103.149.162.194', '176.110.121.90', '157.119.234.50', '34.145.126.174', '180.87.102.68', '45.199.148.4', '155.138.217.58', '59.149.126.19', '219.73.24.143', '118.99.100.228', '45.12.32.6', '80.48.119.28', '58.26.138.171', '45.152.188.210', '15.188.36.82', '194.5.193.183', '103.216.103.26', '201.134.205.167', '101.32.29.246', '180.87.102.69', '209.141.56.127', '103.105.49.53', '41.79.191.183', '103.142.141.71', '103.47.200.12', '167.86.90.94', '172.105.228.153', '45.43.60.76', '74.141.186.101', '194.233.73.105', '45.199.148.2', '45.199.148.36', '38.94.111.208', '88.198.24.108', '206.253.164.146', '206.253.164.108', '5.252.161.48', '80.59.199.212', '103.142.140.22', '159.65.5.141', '171.96.111.209', '45.172.110.86', '5.44.54.103', '176.236.85.246', '103.47.66.150', '190.108.85.98', '3.239.31.229', '34.122.246.161', '103.156.249.54', '211.43.214.205', '103.194.172.182', '77.236.252.187', '201.91.82.155', '91.214.31.234', '109.74.202.142', '191.97.18.177', '156.155.101.34', '89.133.95.177', '103.94.122.14', '43.243.172.2', '212.115.232.79', '3.235.127.194', '95.211.184.218', '128.199.97.42', '13.234.13.40', '176.114.6.132', '91.234.127.222', '43.134.97.78', '3.131.192.183', '116.58.254.197', '80.244.226.92', '194.44.15.222', '131.196.114.3', '175.139.179.65', '186.219.96.47', '113.254.178.224', '77.238.146.153', '195.182.152.238', '45.121.216.99', '123.200.20.242', '58.185.12.166', '116.251.214.12', '103.96.79.73', '101.51.106.70', '117.20.216.218', '41.222.209.9', '118.185.38.153', '185.239.56.245', '82.155.201.123', '135.181.49.81', '187.216.90.46', '162.55.170.151', '183.81.156.130', '103.241.227.107', '62.78.84.159', '103.145.133.22', '109.248.222.215', '186.0.176.147', '101.53.158.48', '123.231.221.242', '47.241.254.115', '139.180.131.87', '18.179.120.38', '165.227.100.166', '64.225.16.208', '89.40.208.180', '43.225.23.131', '119.81.189.194', '34.125.223.33', '194.233.69.90', '150.109.32.166', '168.138.207.12', '45.11.1.63', '47.241.19.33', '202.57.37.197', '66.42.57.230', '103.47.200.5', '178.124.208.8', '34.125.70.166', '13.232.92.6', '18.141.184.73', '47.74.18.244', '185.162.142.81', '63.209.154.34', '45.172.111.12', '77.236.237.177', '182.16.242.4', '36.94.56.90', '190.108.95.205', '103.26.247.129', '170.244.208.14', '46.209.115.203', '36.95.142.26', '202.191.108.42', '188.133.137.9', '24.43.140.138', '103.111.137.226', '54.38.51.131', '41.254.53.66', '166.121.37.10', '45.233.244.143', '45.189.86.133', '103.239.200.246', '152.67.42.114', '209.40.237.43', '45.6.103.150', '36.92.196.141', '131.72.69.1', '58.82.154.3', '178.219.161.211', '91.243.192.26', '182.253.140.250', '116.197.155.25', '195.158.2.229', '213.157.47.38', '190.85.34.140', '138.117.85.231', '206.125.41.130', '203.142.71.50', '186.30.117.146', '200.122.226.44', '188.113.130.67', '103.151.246.66', '178.63.7.176', '18.158.88.79', '197.231.176.250', '45.174.248.51', '27.72.95.176', '36.72.182.99', '200.89.83.130', '177.200.238 ...
