# %% [markdown]
# # Google Vision AI JSON Output Tinker
# ## Alexander O. Smith
# ## Created: August 14 2021
# This script is intended to search through the JSON output of a set of images, create notes about what might be useful, and to explore the limitations of using Vision AI output.

# %%
#install.packages('jsonlite')

# %%
library(rjson)                        #to search JSON files
setwd('./GoogleVisionAITestData/')    #datadirectory

# %%
file <- fromJSON(file='AndThatsAFact1.json')

# %%
file
# Out:
# $cropHintsAnnotation
# $cropHintsAnnotation$cropHints
# $cropHintsAnnotation$cropHints[[1]]
# $cropHintsAnnotation$cropHints[[1]]$boundingPoly
# $cropHintsAnnotation$cropHints[[1]]$boundingPoly$vertices
# $cropHintsAnnotation$cropHints[[1]]$boundingPoly$vertices[[1]]
# list()
#
# $cropHintsAnnotation$cropHints[[1]]$boundingPoly$vertices[[2]]
# $cropHintsAnnotation$cropHints[[1]]$boundingPoly$vertices[[2]]$x
# [1] 416
#
#
# $cropHintsAnnotation$cropHints[[1]]$boundingPoly$vertices[[3]]
# $cropHintsAnnotation$cropHints[[1]]$boundingPoly$vertices[[3]]$x
# [1] 416
#
# $cropHintsAnnotation$cropHints[[1]]$boundingPoly$vertices[[3]]$y
# [1] 520
#
#
# $cropHintsAnnotation$cropHints[[1]]$boundingPoly$vertices[[4]]
# $cropHintsAnnotation$cropHints[[1]]$boundingPoly$vertices[[4]]$y
# [1] 520
#
#
#
#
# $cropHintsAnnotation$cropHints[[1]]$confidence
# [1] 0.245359
#
# $cropHintsAnnotation$cropHints[[1]]$importanceFraction
# [1] 1
#
#
# $cropHintsAnnotation$cropHints[[2]]
# ...

# %%
file['labelAnnotations']
# Out:
# [[1]]
# [[1]]$description
# [1] "Gesture"
#
# [[1]]$mid
# [1] "/m/0244x1"
#
# [[1]]$score
# [1] 0.8526049
#
# [[1]]$topicality
# [1] 0.8526049
#
#
# [[2]]
# [[2]]$description
# [1] "Beard"
#
# [[2]]$mid
# [1] "/m/015h_t"
#
# [[2]]$score
# [1] 0.8104379
#
# [[2]]$topicality
# [1] 0.8104379
#
#
# [[3]]
# [[3]]$description
# [1] "Font"
#
# [[3]]$mid
# [1] "/m/03gq5hm"
#
# [[3]]$score
# [1] 0.7994364
#
# [[3]]$topicality
# [1] 0.7994364
#
#
# [[4]]
# [[4]]$description
# [1] "T-shirt"
#
# [[4]]$mid
# [1] "/m/013s93"
#
# [[4]]$score
# [1] 0.7309455
#
# [[4]]$topicality
# [1] 0.7309455
#
#
# [[5]]
# [[5]]$description
# [1] "Fun"
#
# [[5]]$mid
# [1] "/m/0ds99lh"
#
# [[5]]$score
# [1] 0.6929389
#
# [[5]]$topicality
# [1] 0.6929389
#
#
# [[6]]
# [[6]]$description
# [1] "Room"
#
# [[6]]$mid
# [1] "/m/06ht1"
#
# [[6]]$score
# [1] 0.6791245
#
# [[6]]$topicality
# [1] 0.6791245
#
#
# [[7]]
# [[7]]$description
# [1] "Event"
#
# [[7]]$mid
# [1] "/m/081pkj"
#
# [[7]]$score
# [1] 0.6747045
#
# ...

# %%
file['localizedObjectAnnotations']
# Out:
# $localizedObjectAnnotations
# $localizedObjectAnnotations[[1]]
# $localizedObjectAnnotations[[1]]$boundingPoly
# $localizedObjectAnnotations[[1]]$boundingPoly$normalizedVertices
# $localizedObjectAnnotations[[1]]$boundingPoly$normalizedVertices[[1]]
# $localizedObjectAnnotations[[1]]$boundingPoly$normalizedVertices[[1]]$x
# [1] 0.7769268
#
# $localizedObjectAnnotations[[1]]$boundingPoly$normalizedVertices[[1]]$y
# [1] 0.03324413
#
#
# $localizedObjectAnnotations[[1]]$boundingPoly$normalizedVertices[[2]]
# $localizedObjectAnnotations[[1]]$boundingPoly$normalizedVertices[[2]]$x
# [1] 0.9769958
#
# $localizedObjectAnnotations[[1]]$boundingPoly$normalizedVertices[[2]]$y
# [1] 0.03324413
#
#
# $localizedObjectAnnotations[[1]]$boundingPoly$normalizedVertices[[3]]
# $localizedObjectAnnotations[[1]]$boundingPoly$normalizedVertices[[3]]$x
# [1] 0.9769958
#
# $localizedObjectAnnotations[[1]]$boundingPoly$normalizedVertices[[3]]$y
# [1] 0.1982922
#
#
# ...

# %%
file['textAnnotations']
# Out:
# [[1]]
# [[1]]$boundingPoly
# [[1]]$boundingPoly$vertices
# [[1]]$boundingPoly$vertices[[1]]
# [[1]]$boundingPoly$vertices[[1]]$x
# [1] 31
#
# [[1]]$boundingPoly$vertices[[1]]$y
# [1] 28
#
#
# [[1]]$boundingPoly$vertices[[2]]
# [[1]]$boundingPoly$vertices[[2]]$x
# [1] 642
#
# [[1]]$boundingPoly$vertices[[2]]$y
# [1] 28
#
#
# [[1]]$boundingPoly$vertices[[3]]
# [[1]]$boundingPoly$vertices[[3]]$x
# [1] 642
#
# [[1]]$boundingPoly$vertices[[3]]$y
# [1] 534
#
#
# [[1]]$boundingPoly$vertices[[4]]
# [[1]]$boundingPoly$vertices[[4]]$x
# [1] 31
#
# [[1]]$boundingPoly$vertices[[4]]$y
# [1] 534
#
#
#
#
# [[1]]$description
# [1] "RU\nALLA\nIf your meme\nhas too many\nwords people will\nskip it\nV50M\nand that's a fact\n"
#
# [[1]]$locale
# [1] "en"
#
#
# [[2]]
# [[2]]$boundingPoly
# [[2]]$boundingPoly$vertices
# [[2]]$boundingPoly$vertices[[1]]
# [[2]]$boundingPoly$vertices[[1]]$x
# [1] 571
#
# [[2]]$boundingPoly$vertices[[1]]$y
# [1] 28
#
#
# [[2]]$boundingPoly$vertices[[2]]
# ...
